# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.13.0'

# %% [markdown]
# ## Importing Dataset

# %%
dataset = pd.read_csv('./data/csv_experiments.csv')

# %%
dataset
# Out:
#       Unnamed: 0  experiment_name            experiment_start  \
# 0              0  zoo_iot01_00000  2019-05-03 16:08:03.361407
# 1              1  zoo_iot01_00001  2019-05-03 16:09:33.769141
# 2              2  zoo_iot01_00002  2019-05-03 16:11:02.395897
# 3              3  zoo_iot01_00003  2019-05-03 16:12:32.132698
# 4              4  zoo_iot01_00004  2019-05-03 16:14:01.776285
# ...          ...              ...                         ...
# 1595        1595  zoo_iot01_01595  2019-05-05 07:58:14.841128
# 1596        1596  zoo_iot01_01596  2019-05-05 07:59:45.156999
# 1597        1597  zoo_iot01_01597  2019-05-05 08:01:15.113281
# 1598        1598  zoo_iot01_01598  2019-05-05 08:02:45.302724
# 1599        1599  zoo_iot01_01599  2019-05-05 08:04:15.398888
#
#                  experiment_stop  \
# 0     2019-05-03 16:09:03.422573
# 1     2019-05-03 16:10:33.830241
# 2     2019-05-03 16:12:02.453342
# 3     2019-05-03 16:13:32.193843
# 4     2019-05-03 16:15:01.837396
# ...                          ...
# 1595  2019-05-05 07:59:14.898471
# 1596  2019-05-05 08:00:45.217393
# 1597  2019-05-05 08:02:15.174651
# 1598  2019-05-05 08:03:45.363962
# 1599  2019-05-05 08:05:15.460152
#
#         metric__mp.input.vdu01.0__malaria_clientid  \
# 0     Aggregate stats (simple avg) for 1 processes
# 1     Aggregate stats (simple avg) for 1 processes
# 2     Aggregate stats (simple avg) for 1 processes
# 3     Aggregate stats (simple avg) for 1 processes
# 4     Aggregate stats (simple avg) for 1 processes
# ...                                            ...
# 1595  Aggregate stats (simple avg) for 1 processes
# 1596  Aggregate stats (simple avg) for 1 processes
# 1597  Aggregate stats (simple avg) for 1 processes
# 1598  Aggregate stats (simple avg) for 1 processes
# 1599  Aggregate stats (simple avg) for 1 processes
#
#       metric__mp.input.vdu01.0__malaria_count_ok  \
# 0                                          10000
# 1                                          10000
# 2                                          10000
# 3                                          10000
# 4                                          10000
# ...                                          ...
# 1595                                       10000
# 1596                                       10000
# 1597                                       10000
# 1598                                       10000
# 1599                                       10000
#
#       metric__mp.input.vdu01.0__malaria_count_total  \
# 0                                             10000
# 1                                             10000
# 2                                             10000
# 3                                             10000
# 4                                             10000
# ...                                             ...
# 1595                                          10000
# 1596                                          10000
# 1597                                          10000
# 1598                                          10000
# 1599                                          10000
#
#       metric__mp.input.vdu01.0__malaria_msgs_per_sec  \
# 0                                        1442.486697
# 1                                        1414.498769
# 2                                        1444.074802
# 3                                        1440.336513
# 4                                        1438.958843
# ...                                              ...
# 1595                                      329.944637
# 1596                                      327.484944
# 1597                                      339.133717
# 1598                                      329.418297
# 1599                                      336.934658
#
#       metric__mp.input.vdu01.0__malaria_rate_ok  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 1595                                          1
# 1596                                          1
# 1597                                          1
# 1598                                          1
# 1599                                          1
#
#       metric__mp.input.vdu01.0__malaria_time_max  ...  \
# 0                                    5593.250036  ...
# 1                                    5973.675966  ...
# 2                                    5536.617994  ...
# 3                                    5938.068867  ...
# 4                                    5673.784018  ...
# ...                                          ...  ...
# 1595                                   41.346073  ...
# 1596                                  579.529047  ...
# 1597                                   42.486906  ...
# 1598                                   44.168949  ...
# 1599                                   43.051004  ...
#
#       param__header__all__time_limit  param__mp__mp.input__address  \
# 0                                 60                   20.0.0.1/24
# 1                                 60                   20.0.0.1/24
# 2                                 60                   20.0.0.1/24
# 3                                 60                   20.0.0.1/24
# 4                                 60                   20.0.0.1/24
# ...                              ...                           ...
# 1595                              60                   20.0.0.1/24
# 1596                              60                   20.0.0.1/24
# 1597                              60                   20.0.0.1/24
# 1598                              60                   20.0.0.1/24
# 1599                              60                   20.0.0.1/24
#
#       param__mp__mp.input__connection_point  param__mp__mp.input__container  \
# 0                                  ns:input           mpeuster/tng-bench-mp
# 1                                  ns:input           mpeuster/tng-bench-mp
# 2                                  ns:input           mpeuster/tng-bench-mp
# 3                                  ns:input           mpeuster/tng-bench-mp
# 4                                  ns:input           mpeuster/tng-bench-mp
# ...                                     ...                             ...
# 1595                               ns:input           mpeuster/tng-bench-mp
# 1596                               ns:input           mpeuster/tng-bench-mp
# 1597                               ns:input           mpeuster/tng-bench-mp
# 1598                               ns:input           mpeuster/tng-bench-mp
# 1599                               ns:input           mpeuster/tng-bench-mp
#
#       param__mp__mp.input__name  param__mp__mp.output__address  \
# 0                      mp.input                  40.0.0.254/24
# 1                      mp.input                  40.0.0.254/24
# 2                      mp.input                  40.0.0.254/24
# 3                      mp.input                  40.0.0.254/24
# 4                      mp.input                  40.0.0.254/24
# ...                         ...                            ...
# 1595                   mp.input                  40.0.0.254/24
# 1596                   mp.input                  40.0.0.254/24
# 1597                   mp.input                  40.0.0.254/24
# 1598                   mp.input                  40.0.0.254/24
# 1599                   mp.input                  40.0.0.254/24
#
#       param__mp__mp.output__connection_point  param__mp__mp.output__container  \
# 0                                  ns:output            mpeuster/tng-bench-mp
# 1                                  ns:output            mpeuster/tng-bench-mp
# 2                                  ns:output            mpeuster/tng-bench-mp
# 3                                  ns:output            mpeuster/tng-bench-mp
# 4                                  ns:output            mpeuster/tng-bench-mp
# ...                                      ...                              ...
# 1595                               ns:output            mpeuster/tng-bench-mp
# 1596                               ns:output            mpeuster/tng-bench-mp
# 1597                               ns:output            mpeuster/tng-bench-mp
# 1598                               ns:output            mpeuster/tng-bench-mp
# 1599                               ns:output            mpeuster/tng-bench-mp
#
#       param__mp__mp.output__name  run_id
# 0                      mp.output       0
# 1                      mp.output       1
# 2                      mp.output       2
# 3                      mp.output       3
# 4                      mp.output       4
# ...                          ...     ...
# 1595                   mp.output    1595
# 1596                   mp.output    1596
# 1597                   mp.output    1597
# 1598                   mp.output    1598
# 1599                   mp.output    1599
#
# [1600 rows x 312 columns]

# %%
def all_entries_zero(column):
    return column.all() == 0

columns_to_drop = dataset.columns[dataset.apply(all_entries_zero)]
dataset_new = dataset.drop(columns_to_drop, axis=1)

# %%
dataset_new
# Out:
#       experiment_name            experiment_start             experiment_stop  \
# 0     zoo_iot01_00000  2019-05-03 16:08:03.361407  2019-05-03 16:09:03.422573
# 1     zoo_iot01_00001  2019-05-03 16:09:33.769141  2019-05-03 16:10:33.830241
# 2     zoo_iot01_00002  2019-05-03 16:11:02.395897  2019-05-03 16:12:02.453342
# 3     zoo_iot01_00003  2019-05-03 16:12:32.132698  2019-05-03 16:13:32.193843
# 4     zoo_iot01_00004  2019-05-03 16:14:01.776285  2019-05-03 16:15:01.837396
# ...               ...                         ...                         ...
# 1595  zoo_iot01_01595  2019-05-05 07:58:14.841128  2019-05-05 07:59:14.898471
# 1596  zoo_iot01_01596  2019-05-05 07:59:45.156999  2019-05-05 08:00:45.217393
# 1597  zoo_iot01_01597  2019-05-05 08:01:15.113281  2019-05-05 08:02:15.174651
# 1598  zoo_iot01_01598  2019-05-05 08:02:45.302724  2019-05-05 08:03:45.363962
# 1599  zoo_iot01_01599  2019-05-05 08:04:15.398888  2019-05-05 08:05:15.460152
#
#         metric__mp.input.vdu01.0__malaria_clientid  \
# 0     Aggregate stats (simple avg) for 1 processes
# 1     Aggregate stats (simple avg) for 1 processes
# 2     Aggregate stats (simple avg) for 1 processes
# 3     Aggregate stats (simple avg) for 1 processes
# 4     Aggregate stats (simple avg) for 1 processes
# ...                                            ...
# 1595  Aggregate stats (simple avg) for 1 processes
# 1596  Aggregate stats (simple avg) for 1 processes
# 1597  Aggregate stats (simple avg) for 1 processes
# 1598  Aggregate stats (simple avg) for 1 processes
# 1599  Aggregate stats (simple avg) for 1 processes
#
#       metric__mp.input.vdu01.0__malaria_count_ok  \
# 0                                          10000
# 1                                          10000
# 2                                          10000
# 3                                          10000
# 4                                          10000
# ...                                          ...
# 1595                                       10000
# 1596                                       10000
# 1597                                       10000
# 1598                                       10000
# 1599                                       10000
#
#       metric__mp.input.vdu01.0__malaria_count_total  \
# 0                                             10000
# 1                                             10000
# 2                                             10000
# 3                                             10000
# 4                                             10000
# ...                                             ...
# 1595                                          10000
# 1596                                          10000
# 1597                                          10000
# 1598                                          10000
# 1599                                          10000
#
#       metric__mp.input.vdu01.0__malaria_msgs_per_sec  \
# 0                                        1442.486697
# 1                                        1414.498769
# 2                                        1444.074802
# 3                                        1440.336513
# 4                                        1438.958843
# ...                                              ...
# 1595                                      329.944637
# 1596                                      327.484944
# 1597                                      339.133717
# 1598                                      329.418297
# 1599                                      336.934658
#
#       metric__mp.input.vdu01.0__malaria_rate_ok  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 1595                                          1
# 1596                                          1
# 1597                                          1
# 1598                                          1
# 1599                                          1
#
#       metric__mp.input.vdu01.0__malaria_time_max  \
# 0                                    5593.250036
# 1                                    5973.675966
# 2                                    5536.617994
# 3                                    5938.068867
# 4                                    5673.784018
# ...                                          ...
# 1595                                   41.346073
# 1596                                  579.529047
# 1597                                   42.486906
# 1598                                   44.168949
# 1599                                   43.051004
#
#       metric__mp.input.vdu01.0__malaria_time_mean  ...  \
# 0                                     3412.720682  ...
# 1                                     3756.159934  ...
# 2                                     3317.213071  ...
# 3                                     3657.318589  ...
# 4                                     3464.631551  ...
# ...                                           ...  ...
# 1595                                     2.839258  ...
# 1596                                     2.590731  ...
# 1597                                     2.803832  ...
# 1598                                     3.003782  ...
# 1599                                     2.642752  ...
#
#       param__func__mp.output__mem_swap_max  param__header__all__time_limit  \
# 0                                      NaN                              60
# 1                                      NaN                              60
# 2                                      NaN                              60
# 3                                      NaN                              60
# 4                                      NaN                              60
# ...                                    ...                             ...
# 1595                                   NaN                              60
# 1596                                   NaN                              60
# 1597                                   NaN                              60
# 1598                                   NaN                              60
# 1599                                   NaN                              60
#
#       param__mp__mp.input__address  param__mp__mp.input__connection_point  \
# 0                      20.0.0.1/24                               ns:input
# 1                      20.0.0.1/24                               ns:input
# 2                      20.0.0.1/24                               ns:input
# 3                      20.0.0.1/24                               ns:input
# 4                      20.0.0.1/24                               ns:input
# ...                            ...                                    ...
# 1595                   20.0.0.1/24                               ns:input
# 1596                   20.0.0.1/24                               ns:input
# 1597                   20.0.0.1/24                               ns:input
# 1598                   20.0.0.1/24                               ns:input
# 1599                   20.0.0.1/24                               ns:input
#
#       param__mp__mp.input__container  param__mp__mp.input__name  \
# 0              mpeuster/tng-bench-mp                   mp.input
# 1              mpeuster/tng-bench-mp                   mp.input
# 2              mpeuster/tng-bench-mp                   mp.input
# 3              mpeuster/tng-bench-mp                   mp.input
# 4              mpeuster/tng-bench-mp                   mp.input
# ...                              ...                        ...
# 1595           mpeuster/tng-bench-mp                   mp.input
# 1596           mpeuster/tng-bench-mp                   mp.input
# 1597           mpeuster/tng-bench-mp                   mp.input
# 1598           mpeuster/tng-bench-mp                   mp.input
# 1599           mpeuster/tng-bench-mp                   mp.input
#
#       param__mp__mp.output__address  param__mp__mp.output__connection_point  \
# 0                     40.0.0.254/24                               ns:output
# 1                     40.0.0.254/24                               ns:output
# 2                     40.0.0.254/24                               ns:output
# 3                     40.0.0.254/24                               ns:output
# 4                     40.0.0.254/24                               ns:output
# ...                             ...                                     ...
# 1595                  40.0.0.254/24                               ns:output
# 1596                  40.0.0.254/24                               ns:output
# 1597                  40.0.0.254/24                               ns:output
# 1598                  40.0.0.254/24                               ns:output
# 1599                  40.0.0.254/24                               ns:output
#
#       param__mp__mp.output__container  param__mp__mp.output__name
# 0               mpeuster/tng-bench-mp                   mp.output
# 1               mpeuster/tng-bench-mp                   mp.output
# 2               mpeuster/tng-bench-mp                   mp.output
# 3               mpeuster/tng-bench-mp                   mp.output
# 4               mpeuster/tng-bench-mp                   mp.output
# ...                               ...                         ...
# 1595            mpeuster/tng-bench-mp                   mp.output
# 1596            mpeuster/tng-bench-mp                   mp.output
# 1597            mpeuster/tng-bench-mp                   mp.output
# 1598            mpeuster/tng-bench-mp                   mp.output
# 1599            mpeuster/tng-bench-mp                   mp.output
#
# [1600 rows x 90 columns]

# %% [markdown]
# # Checking for any Null values in dataset

# %%
dataset_new = dataset_new.replace('', np.nan)
dataset_new.isnull().sum()
# Out:
# experiment_name                               0
# experiment_start                              0
# experiment_stop                               0
# metric__mp.input.vdu01.0__malaria_clientid    0
# metric__mp.input.vdu01.0__malaria_count_ok    0
#                                              ..
# param__mp__mp.input__name                     0
# param__mp__mp.output__address                 0
# param__mp__mp.output__connection_point        0
# param__mp__mp.output__container               0
# param__mp__mp.output__name                    0
# Length: 90, dtype: int64

# %%
dataset_new = dataset_new.dropna(axis=1, how='all')
dataset_new.isnull().sum()
# Out:
# experiment_name                               0
# experiment_start                              0
# experiment_stop                               0
# metric__mp.input.vdu01.0__malaria_clientid    0
# metric__mp.input.vdu01.0__malaria_count_ok    0
#                                              ..
# param__mp__mp.input__name                     0
# param__mp__mp.output__address                 0
# param__mp__mp.output__connection_point        0
# param__mp__mp.output__container               0
# param__mp__mp.output__name                    0
# Length: 80, dtype: int64

# %%
dataset_new
# Out:
#       experiment_name            experiment_start             experiment_stop  \
# 0     zoo_iot01_00000  2019-05-03 16:08:03.361407  2019-05-03 16:09:03.422573
# 1     zoo_iot01_00001  2019-05-03 16:09:33.769141  2019-05-03 16:10:33.830241
# 2     zoo_iot01_00002  2019-05-03 16:11:02.395897  2019-05-03 16:12:02.453342
# 3     zoo_iot01_00003  2019-05-03 16:12:32.132698  2019-05-03 16:13:32.193843
# 4     zoo_iot01_00004  2019-05-03 16:14:01.776285  2019-05-03 16:15:01.837396
# ...               ...                         ...                         ...
# 1595  zoo_iot01_01595  2019-05-05 07:58:14.841128  2019-05-05 07:59:14.898471
# 1596  zoo_iot01_01596  2019-05-05 07:59:45.156999  2019-05-05 08:00:45.217393
# 1597  zoo_iot01_01597  2019-05-05 08:01:15.113281  2019-05-05 08:02:15.174651
# 1598  zoo_iot01_01598  2019-05-05 08:02:45.302724  2019-05-05 08:03:45.363962
# 1599  zoo_iot01_01599  2019-05-05 08:04:15.398888  2019-05-05 08:05:15.460152
#
#         metric__mp.input.vdu01.0__malaria_clientid  \
# 0     Aggregate stats (simple avg) for 1 processes
# 1     Aggregate stats (simple avg) for 1 processes
# 2     Aggregate stats (simple avg) for 1 processes
# 3     Aggregate stats (simple avg) for 1 processes
# 4     Aggregate stats (simple avg) for 1 processes
# ...                                            ...
# 1595  Aggregate stats (simple avg) for 1 processes
# 1596  Aggregate stats (simple avg) for 1 processes
# 1597  Aggregate stats (simple avg) for 1 processes
# 1598  Aggregate stats (simple avg) for 1 processes
# 1599  Aggregate stats (simple avg) for 1 processes
#
#       metric__mp.input.vdu01.0__malaria_count_ok  \
# 0                                          10000
# 1                                          10000
# 2                                          10000
# 3                                          10000
# 4                                          10000
# ...                                          ...
# 1595                                       10000
# 1596                                       10000
# 1597                                       10000
# 1598                                       10000
# 1599                                       10000
#
#       metric__mp.input.vdu01.0__malaria_count_total  \
# 0                                             10000
# 1                                             10000
# 2                                             10000
# 3                                             10000
# 4                                             10000
# ...                                             ...
# 1595                                          10000
# 1596                                          10000
# 1597                                          10000
# 1598                                          10000
# 1599                                          10000
#
#       metric__mp.input.vdu01.0__malaria_msgs_per_sec  \
# 0                                        1442.486697
# 1                                        1414.498769
# 2                                        1444.074802
# 3                                        1440.336513
# 4                                        1438.958843
# ...                                              ...
# 1595                                      329.944637
# 1596                                      327.484944
# 1597                                      339.133717
# 1598                                      329.418297
# 1599                                      336.934658
#
#       metric__mp.input.vdu01.0__malaria_rate_ok  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
# ...                                         ...
# 1595                                          1
# 1596                                          1
# 1597                                          1
# 1598                                          1
# 1599                                          1
#
#       metric__mp.input.vdu01.0__malaria_time_max  \
# 0                                    5593.250036
# 1                                    5973.675966
# 2                                    5536.617994
# 3                                    5938.068867
# 4                                    5673.784018
# ...                                          ...
# 1595                                   41.346073
# 1596                                  579.529047
# 1597                                   42.486906
# 1598                                   44.168949
# 1599                                   43.051004
#
#       metric__mp.input.vdu01.0__malaria_time_mean  ...  \
# 0                                     3412.720682  ...
# 1                                     3756.159934  ...
# 2                                     3317.213071  ...
# 3                                     3657.318589  ...
# 4                                     3464.631551  ...
# ...                                           ...  ...
# 1595                                     2.839258  ...
# 1596                                     2.590731  ...
# 1597                                     2.803832  ...
# 1598                                     3.003782  ...
# 1599                                     2.642752  ...
#
#       param__func__mp.output__cpu_cores  param__header__all__time_limit  \
# 0                                    15                              60
# 1                                    15                              60
# 2                                    15                              60
# 3                                    15                              60
# 4                                    15                              60
# ...                                 ...                             ...
# 1595                                 15                              60
# 1596                                 15                              60
# 1597                                 15                              60
# 1598                                 15                              60
# 1599                                 15                              60
#
#       param__mp__mp.input__address  param__mp__mp.input__connection_point  \
# 0                      20.0.0.1/24                               ns:input
# 1                      20.0.0.1/24                               ns:input
# 2                      20.0.0.1/24                               ns:input
# 3                      20.0.0.1/24                               ns:input
# 4                      20.0.0.1/24                               ns:input
# ...                            ...                                    ...
# 1595                   20.0.0.1/24                               ns:input
# 1596                   20.0.0.1/24                               ns:input
# 1597                   20.0.0.1/24                               ns:input
# 1598                   20.0.0.1/24                               ns:input
# 1599                   20.0.0.1/24                               ns:input
#
#       param__mp__mp.input__container  param__mp__mp.input__name  \
# 0              mpeuster/tng-bench-mp                   mp.input
# 1              mpeuster/tng-bench-mp                   mp.input
# 2              mpeuster/tng-bench-mp                   mp.input
# 3              mpeuster/tng-bench-mp                   mp.input
# 4              mpeuster/tng-bench-mp                   mp.input
# ...                              ...                        ...
# 1595           mpeuster/tng-bench-mp                   mp.input
# 1596           mpeuster/tng-bench-mp                   mp.input
# 1597           mpeuster/tng-bench-mp                   mp.input
# 1598           mpeuster/tng-bench-mp                   mp.input
# 1599           mpeuster/tng-bench-mp                   mp.input
#
#       param__mp__mp.output__address  param__mp__mp.output__connection_point  \
# 0                     40.0.0.254/24                               ns:output
# 1                     40.0.0.254/24                               ns:output
# 2                     40.0.0.254/24                               ns:output
# 3                     40.0.0.254/24                               ns:output
# 4                     40.0.0.254/24                               ns:output
# ...                             ...                                     ...
# 1595                  40.0.0.254/24                               ns:output
# 1596                  40.0.0.254/24                               ns:output
# 1597                  40.0.0.254/24                               ns:output
# 1598                  40.0.0.254/24                               ns:output
# 1599                  40.0.0.254/24                               ns:output
#
#       param__mp__mp.output__container  param__mp__mp.output__name
# 0               mpeuster/tng-bench-mp                   mp.output
# 1               mpeuster/tng-bench-mp                   mp.output
# 2               mpeuster/tng-bench-mp                   mp.output
# 3               mpeuster/tng-bench-mp                   mp.output
# 4               mpeuster/tng-bench-mp                   mp.output
# ...                               ...                         ...
# 1595            mpeuster/tng-bench-mp                   mp.output
# 1596            mpeuster/tng-bench-mp                   mp.output
# 1597            mpeuster/tng-bench-mp                   mp.output
# 1598            mpeuster/tng-bench-mp                   mp.output
# 1599            mpeuster/tng-bench-mp                   mp.output
#
# [1600 rows x 80 columns]

# %%
def all_values_same(column):
    return column.nunique() == 1

columns_to_drop = dataset_new.columns[dataset_new.apply(all_values_same)]
dataset_new = dataset_new.drop(columns_to_drop, axis=1)

# %%
dataset_new
# Out:
#       experiment_name            experiment_start             experiment_stop  \
# 0     zoo_iot01_00000  2019-05-03 16:08:03.361407  2019-05-03 16:09:03.422573
# 1     zoo_iot01_00001  2019-05-03 16:09:33.769141  2019-05-03 16:10:33.830241
# 2     zoo_iot01_00002  2019-05-03 16:11:02.395897  2019-05-03 16:12:02.453342
# 3     zoo_iot01_00003  2019-05-03 16:12:32.132698  2019-05-03 16:13:32.193843
# 4     zoo_iot01_00004  2019-05-03 16:14:01.776285  2019-05-03 16:15:01.837396
# ...               ...                         ...                         ...
# 1595  zoo_iot01_01595  2019-05-05 07:58:14.841128  2019-05-05 07:59:14.898471
# 1596  zoo_iot01_01596  2019-05-05 07:59:45.156999  2019-05-05 08:00:45.217393
# 1597  zoo_iot01_01597  2019-05-05 08:01:15.113281  2019-05-05 08:02:15.174651
# 1598  zoo_iot01_01598  2019-05-05 08:02:45.302724  2019-05-05 08:03:45.363962
# 1599  zoo_iot01_01599  2019-05-05 08:04:15.398888  2019-05-05 08:05:15.460152
#
#       metric__mp.input.vdu01.0__malaria_msgs_per_sec  \
# 0                                        1442.486697
# 1                                        1414.498769
# 2                                        1444.074802
# 3                                        1440.336513
# 4                                        1438.958843
# ...                                              ...
# 1595                                      329.944637
# 1596                                      327.484944
# 1597                                      339.133717
# 1598                                      329.418297
# 1599                                      336.934658
#
#       metric__mp.input.vdu01.0__malaria_time_max  \
# 0                                    5593.250036
# 1                                    5973.675966
# 2                                    5536.617994
# 3                                    5938.068867
# 4                                    5673.784018
# ...                                          ...
# 1595                                   41.346073
# 1596                                  579.529047
# 1597                                   42.486906
# 1598                                   44.168949
# 1599                                   43.051004
#
#       metric__mp.input.vdu01.0__malaria_time_mean  \
# 0                                     3412.720682
# 1                                     3756.159934
# 2                                     3317.213071
# 3                                     3657.318589
# 4                                     3464.631551
# ...                                           ...
# 1595                                     2.839258
# 1596                                     2.590731
# 1597                                     2.803832
# 1598                                     3.003782
# 1599                                     2.642752
#
#       metric__mp.input.vdu01.0__malaria_time_min  \
# 0                                      13.519049
# 1                                      14.099121
# 2                                      11.127949
# 3                                      13.363123
# 4                                      13.432980
# ...                                          ...
# 1595                                    0.054836
# 1596                                    0.052929
# 1597                                    0.072956
# 1598                                    2.301931
# 1599                                    0.054836
#
#       metric__mp.input.vdu01.0__malaria_time_stddev  \
# 0                                       1956.545860
# 1                                       2013.793888
# 2                                       1965.811853
# 3                                       2044.054350
# 4                                       1985.075934
# ...                                             ...
# 1595                                       1.130028
# 1596                                       6.009621
# 1597                                       1.448154
# 1598                                       2.136913
# 1599                                       1.650165
#
#       metric__mp.input.vdu01.0__malaria_time_total  \
# 0                                        14.019541
# 1                                        14.018342
# 2                                        17.021587
# 3                                        17.021670
# 4                                        13.017407
# ...                                            ...
# 1595                                     34.038315
# 1596                                     34.037556
# 1597                                     33.037925
# 1598                                     41.048656
# 1599                                     39.044937
#
#       metric__mp.input.vdu01.0__stat__data__rx_bytes  ...  \
# 0                                           118822.0  ...
# 1                                           117196.0  ...
# 2                                           117964.0  ...
# 3                                           120076.0  ...
# 4                                           116404.0  ...
# ...                                              ...  ...
# 1595                                        710206.0  ...
# 1596                                        784996.0  ...
# 1597                                        706642.0  ...
# 1598                                        698236.0  ...
# 1599                                        751432.0  ...
#
#       metric__vnf0.vdu01.0__stat__lo__rx_packets  \
# 0                                          472.0
# 1                                          472.0
# 2                                          472.0
# 3                                          459.0
# 4                                          472.0
# ...                                          ...
# 1595                                       485.0
# 1596                                       485.0
# 1597                                       485.0
# 1598                                       485.0
# 1599                                       485.0
#
#       metric__vnf0.vdu01.0__stat__lo__tx_bytes  \
# 0                                     104014.0
# 1                                     103885.0
# 2                                     103968.0
# 3                                     101239.0
# 4                                     103884.0
# ...                                        ...
# 1595                                  105800.0
# 1596                                  105921.0
# 1597                                  105894.0
# 1598                                  105667.0
# 1599                                  105742.0
#
#       metric__vnf0.vdu01.0__stat__lo__tx_packets  \
# 0                                          472.0
# 1                                          472.0
# 2                                          472.0
# 3                                          459.0
# 4                                          472.0
# ...                                          ...
# 1595                                       485.0
# 1596                                       485.0
# 1597                                       485.0
# 1598                                       485.0
# 1599                                       485.0
#
#       metric__vnf0.vdu01.0__stat__output__rx_bytes  \
# 0                                         296570.0
# 1                                         301936.0
# 2                                         296860.0
# 3                                         312348.0
# 4                                         294154.0
# ...                                            ...
# 1595                                      702000.0
# 1596                                      785952.0
# 1597                                      741204.0
# 1598                                      873580.0
# 1599                                      700524.0
#
#       metric__vnf0.vdu01.0__stat__output__rx_packets  \
# 0                                             4117.0
# 1                                             4190.0
# 2                                             4126.0
# 3                                             4344.0
# 4                                             4086.0
# ...                                              ...
# 1595                                         10027.0
# 1596                                         11299.0
# 1597                                         10621.0
# 1598                                         12621.0
# 1599                                         10005.0
#
#       metric__vnf0.vdu01.0__stat__output__tx_bytes  \
# 0                                        1430503.0
# 1                                        1459621.0
# 2                                        1416405.0
# 3                                        1479498.0
# 4                                        1408234.0
# ...                                            ...
# 1595                                   101375252.0
# 1596                                   101350129.0
# 1597                                   101291299.0
# 1598                                   101432771.0
# 1599                                   101359133.0
#
#       metric__vnf0.vdu01.0__stat__output__tx_packets  \
# 0                                             4343.0
# 1                                             4423.0
# 2                                             4355.0
# 3                                             4545.0
# 4                                             4307.0
# ...                                              ...
# 1595                                         10026.0
# 1596                                         10037.0
# 1597                                         10044.0
# 1598                                         10047.0
# 1599                                         10028.0
#
#       param__func__de.upb.broker-mosquitto.0.1__cpu_bw  \
# 0                                                  0.1
# 1                                                  0.1
# 2                                                  0.1
# 3                                                  0.1
# 4                                                  0.1
# ...                                                ...
# 1595                                               1.0
# 1596                                               1.0
# 1597                                               1.0
# 1598                                               1.0
# 1599                                               1.0
#
#       param__func__de.upb.broker-mosquitto.0.1__mem_max  \
# 0                                                    64
# 1                                                    64
# 2                                                    64
# 3                                                    64
# 4                                                    64
# ...                                                 ...
# 1595                                                512
# 1596                                                512
# 1597                                                512
# 1598                                                512
# 1599                                                512
#
#                        param__func__mp.input__cmd_start
# 0     malaria publish -t -n 10000 -H 20.0.0.254 -q 1...
# 1     malaria publish -t -n 10000 -H 20.0.0.254 -q 1...
# 2     malaria publish -t -n 10000 -H 20.0.0.254 -q 1...
# 3     malaria publish -t -n 10000 -H 20.0.0.254 -q 1...
# 4     malaria publish -t -n 10000 -H 20.0.0.254 -q 1...
# ...                                                 ...
# 1595  malaria publish -s 10000 -n 10000 -H 20.0.0.25...
# 1596  malaria publish -s 10000 -n 10000 -H 20.0.0.25...
# 1597  malaria publish -s 10000 -n 10000 -H 20.0.0.25...
# 1598  malaria publish -s 10000 -n 10000 -H 20.0.0.25...
# 1599  malaria publish -s 10000 -n 10000 -H 20.0.0.25...
#
# [1600 rows x 56 columns]

# %%
dataset_new.columns
# Out:
# Index(['experiment_name', 'experiment_start', 'experiment_stop',
#        'metric__mp.input.vdu01.0__malaria_msgs_per_sec',
#        'metric__mp.input.vdu01.0__malaria_time_max',
#        'metric__mp.input.vdu01.0__malaria_time_mean',
#        'metric__mp.input.vdu01.0__malaria_time_min',
#        'metric__mp.input.vdu01.0__malaria_time_stddev',
#        'metric__mp.input.vdu01.0__malaria_time_total',
#        'metric__mp.input.vdu01.0__stat__data__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__data__rx_packets',
#        'metric__mp.input.vdu01.0__stat__data__tx_bytes',
#        'metric__mp.input.vdu01.0__stat__data__tx_packets',
#        'metric__mp.input.vdu01.0__stat__eth0__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__eth0__rx_packets',
#        'metric__mp.input.vdu01.0__stat__lo__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__lo__rx_packets',
#        'metric__mp.input.vdu01.0__stat__lo__tx_bytes',
#        'metric__mp.input.vdu01.0__stat__lo__tx_packets',
#        'metric__mp.output.vdu01.0__malaria_clientid',
#        'metric__mp.output.vdu01.0__malaria_flight_time_max',
#        'metric__mp.output.vdu01.0__malaria_flight_time_mean',
#        'metric__mp.output.vdu01.0__malaria_flight_time_min',
#        'metric__mp.output.vdu01.0__malaria_ms_per_msg',
#        'metric__mp.output.vdu01.0__malaria_msg_count',
#        'metric__mp.output.vdu01.0__malaria_msg_per_sec',
#        'metric__mp.output.vdu01.0__malaria_time_total',
#        'metric__mp.output.vdu01.0__stat__data__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__data__rx_packets',
#        'metric__mp.output.vdu01.0__stat__data__tx_bytes',
#        'metric__mp.output.vdu01.0__stat__data__tx_packets',
#        'metric__mp.output.vdu01.0__stat__eth0__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__eth0__rx_packets',
#        'metric__mp.output.vdu01.0__stat__lo__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__lo__rx_packets',
#        'metric__mp.output.vdu01.0__stat__lo__tx_bytes',
#        'metric__mp.output.vdu01.0__stat__lo__tx_packets',
#        'metric__vnf0.vdu01.0__stat__eth0__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__eth0__rx_packets',
#        'metric__vnf0.vdu01.0__stat__eth0__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__eth0__tx_packets',
#        'metric__vnf0.vdu01.0__stat__input__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__input__rx_packets',
#        'metric__vnf0.vdu01.0__stat__input__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__input__tx_packets',
#        'metric__vnf0.vdu01.0__stat__lo__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__lo__rx_packets',
#        'metric__vnf0.vdu01.0__stat__lo__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__lo__tx_packets',
#        'metric__vnf0.vdu01.0__stat__output__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__output__rx_packets',
#        'metric__vnf0.vdu01.0__stat__output__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__output__tx_packets',
#        'param__func__de.upb.broker-mosquitto.0.1__cpu_bw',
#        'param__func__de.upb.broker-mosquitto.0.1__mem_max',
#        'param__func__mp.input__cmd_start'],
#       dtype='object')

# %%
dataset_new = dataset_new.drop(['experiment_name', 'experiment_start', 'experiment_stop', 'metric__mp.output.vdu01.0__malaria_clientid', 'param__func__mp.input__cmd_start'],axis=1)
dataset_new.columns
# Out:
# Index(['metric__mp.input.vdu01.0__malaria_msgs_per_sec',
#        'metric__mp.input.vdu01.0__malaria_time_max',
#        'metric__mp.input.vdu01.0__malaria_time_mean',
#        'metric__mp.input.vdu01.0__malaria_time_min',
#        'metric__mp.input.vdu01.0__malaria_time_stddev',
#        'metric__mp.input.vdu01.0__malaria_time_total',
#        'metric__mp.input.vdu01.0__stat__data__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__data__rx_packets',
#        'metric__mp.input.vdu01.0__stat__data__tx_bytes',
#        'metric__mp.input.vdu01.0__stat__data__tx_packets',
#        'metric__mp.input.vdu01.0__stat__eth0__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__eth0__rx_packets',
#        'metric__mp.input.vdu01.0__stat__lo__rx_bytes',
#        'metric__mp.input.vdu01.0__stat__lo__rx_packets',
#        'metric__mp.input.vdu01.0__stat__lo__tx_bytes',
#        'metric__mp.input.vdu01.0__stat__lo__tx_packets',
#        'metric__mp.output.vdu01.0__malaria_flight_time_max',
#        'metric__mp.output.vdu01.0__malaria_flight_time_mean',
#        'metric__mp.output.vdu01.0__malaria_flight_time_min',
#        'metric__mp.output.vdu01.0__malaria_ms_per_msg',
#        'metric__mp.output.vdu01.0__malaria_msg_count',
#        'metric__mp.output.vdu01.0__malaria_msg_per_sec',
#        'metric__mp.output.vdu01.0__malaria_time_total',
#        'metric__mp.output.vdu01.0__stat__data__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__data__rx_packets',
#        'metric__mp.output.vdu01.0__stat__data__tx_bytes',
#        'metric__mp.output.vdu01.0__stat__data__tx_packets',
#        'metric__mp.output.vdu01.0__stat__eth0__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__eth0__rx_packets',
#        'metric__mp.output.vdu01.0__stat__lo__rx_bytes',
#        'metric__mp.output.vdu01.0__stat__lo__rx_packets',
#        'metric__mp.output.vdu01.0__stat__lo__tx_bytes',
#        'metric__mp.output.vdu01.0__stat__lo__tx_packets',
#        'metric__vnf0.vdu01.0__stat__eth0__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__eth0__rx_packets',
#        'metric__vnf0.vdu01.0__stat__eth0__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__eth0__tx_packets',
#        'metric__vnf0.vdu01.0__stat__input__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__input__rx_packets',
#        'metric__vnf0.vdu01.0__stat__input__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__input__tx_packets',
#        'metric__vnf0.vdu01.0__stat__lo__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__lo__rx_packets',
#        'metric__vnf0.vdu01.0__stat__lo__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__lo__tx_packets',
#        'metric__vnf0.vdu01.0__stat__output__rx_bytes',
#        'metric__vnf0.vdu01.0__stat__output__rx_packets',
#        'metric__vnf0.vdu01.0__stat__output__tx_bytes',
#        'metric__vnf0.vdu01.0__stat__output__tx_packets',
#        'param__func__de.upb.broker-mosquitto.0.1__cpu_bw',
#        'param__func__de.upb.broker-mosquitto.0.1__mem_max'],
#       dtype='object')

# %%
dataset_new.dtypes
# Out:
# metric__mp.input.vdu01.0__malaria_msgs_per_sec         float64
# metric__mp.input.vdu01.0__malaria_time_max             float64
# metric__mp.input.vdu01.0__malaria_time_mean            float64
# metric__mp.input.vdu01.0__malaria_time_min             float64
# metric__mp.input.vdu01.0__malaria_time_stddev          float64
# metric__mp.input.vdu01.0__malaria_time_total           float64
# metric__mp.input.vdu01.0__stat__data__rx_bytes         float64
# metric__mp.input.vdu01.0__stat__data__rx_packets       float64
# metric__mp.input.vdu01.0__stat__data__tx_bytes         float64
# metric__mp.input.vdu01.0__stat__data__tx_packets       float64
# metric__mp.input.vdu01.0__stat__eth0__rx_bytes         float64
# metric__mp.input.vdu01.0__stat__eth0__rx_packets       float64
# metric__mp.input.vdu01.0__stat__lo__rx_bytes           float64
# metric__mp.input.vdu01.0__stat__lo__rx_packets         float64
# metric__mp.input.vdu01.0__stat__lo__tx_bytes           float64
# metric__mp.input.vdu01.0__stat__lo__tx_packets         float64
# metric__mp.output.vdu01.0__malaria_flight_time_max     float64
# metric__mp.output.vdu01.0__malaria_flight_time_mean    float64
# metric__mp.output.vdu01.0__malaria_flight_time_min     float64
# metric__mp.output.vdu01.0__malaria_ms_per_msg          float64
# metric__mp.output.vdu01.0__malaria_msg_count           float64
# metric__mp.output.vdu01.0__malaria_msg_per_sec         float64
# metric__mp.output.vdu01.0__malaria_time_total          float64
# metric__mp.output.vdu01.0__stat__data__rx_bytes        float64
# metric__mp.output.vdu01.0__stat__data__rx_packets      float64
# metric__mp.output.vdu01.0__stat__data__tx_bytes        float64
# metric__mp.output.vdu01.0__stat__data__tx_packets      float64
# metric__mp.output.vdu01.0__stat__eth0__rx_bytes        float64
# metric__mp.output.vdu01.0__stat__eth0__rx_packets      float64
# metric__mp.output.vdu01.0__stat__lo__rx_bytes          float64
# metric__mp.output.vdu01.0__stat__lo__rx_packets        float64
# metric__mp.output.vdu01.0__stat__lo__tx_bytes          float64
# metric__mp.output.vdu01.0__stat__lo__tx_packets        float64
# metric__vnf0.vdu01.0__stat__eth0__rx_bytes             float64
# metric__vnf0.vdu01.0__stat__eth0__rx_packets           float64
# metric__vnf0.vdu01.0__stat__eth0__tx_bytes             float64
# metric__vnf0.vdu01.0__stat__eth0__tx_packets           float64
# metric__vnf0.vdu01.0__stat__input__rx_bytes            float64
# metric__vnf0.vdu01.0__stat__input__rx_packets          float64
# metric__vnf0.vdu01.0__stat__input__tx_bytes            float64
# metric__vnf0.vdu01.0__stat__input__tx_packets          float64
# metric__vnf0.vdu01.0__stat__lo__rx_bytes               float64
# metric__vnf0.vdu01.0__stat__lo__rx_packets             float64
# metric__vnf0.vdu01.0__stat__lo__tx_bytes               float64
# metric__vnf0.vdu01.0__stat__lo__tx_packets             float64
# metric__vnf0.vdu01.0__stat__output__rx_bytes           float64
# metric__vnf0.vdu01.0__stat__output__rx_packets         float64
# metric__vnf0.vdu01.0__stat__output__tx_bytes           float64
# metric__vnf0.vdu01.0__stat__output__tx_packets         float64
# param__func__de.upb.broker-mosquitto.0.1__cpu_bw       float64
# param__func__de.upb.broker-mosquitto.0.1__mem_max        int64
# dtype: object

# %%
dataset_new.isnull().sum()
# Out:
# metric__mp.input.vdu01.0__malaria_msgs_per_sec           0
# metric__mp.input.vdu01.0__malaria_time_max               0
# metric__mp.input.vdu01.0__malaria_time_mean              0
# metric__mp.input.vdu01.0__malaria_time_min               0
# metric__mp.input.vdu01.0__malaria_time_stddev            0
# metric__mp.input.vdu01.0__malaria_time_total             0
# metric__mp.input.vdu01.0__stat__data__rx_bytes           0
# metric__mp.input.vdu01.0__stat__data__rx_packets         0
# metric__mp.input.vdu01.0__stat__data__tx_bytes           0
# metric__mp.input.vdu01.0__stat__data__tx_packets         0
# metric__mp.input.vdu01.0__stat__eth0__rx_bytes           0
# metric__mp.input.vdu01.0__stat__eth0__rx_packets         0
# metric__mp.input.vdu01.0__stat__lo__rx_bytes             0
# metric__mp.input.vdu01.0__stat__lo__rx_packets           0
# metric__mp.input.vdu01.0__stat__lo__tx_bytes             0
# metric__mp.input.vdu01.0__stat__lo__tx_packets           0
# metric__mp.output.vdu01.0__malaria_flight_time_max     762
# metric__mp.output.vdu01.0__malaria_flight_time_mean    762
# metric__mp.output.vdu01.0__malaria_flight_time_min     762
# metric__mp.output.vdu01.0__malaria_ms_per_msg          762
# metric__mp.output.vdu01.0__malaria_msg_count           762
# metric__mp.output.vdu01.0__malaria_msg_per_sec         762
# metric__mp.output.vdu01.0__malaria_time_total          762
# metric__mp.output.vdu01.0__stat__data__rx_bytes          0
# metric__mp.output.vdu01.0__stat__data__rx_packets        0
# metric__mp.output.vdu01.0__stat__data__tx_bytes          0
# metric__mp.output.vdu01.0__stat__data__tx_packets        0
# metric__mp.output.vdu01.0__stat__eth0__rx_bytes          0
# metric__mp.output.vdu01.0__stat__eth0__rx_packets        0
# metric__mp.output.vdu01.0__stat__lo__rx_bytes            0
# metric__mp.output.vdu01.0__stat__lo__rx_packets          0
# metric__mp.output.vdu01.0__stat__lo__tx_bytes            0
# metric__mp.output.vdu01.0__stat__lo__tx_packets          0
# metric__vnf0.vdu01.0__stat__eth0__rx_bytes               0
# metric__vnf0.vdu01.0__stat__eth0__rx_packets             0
# metric__vnf0.vdu01.0__stat__eth0__tx_bytes               0
# metric__vnf0.vdu01.0__stat__eth0__tx_packets             0
# metric__vnf0.vdu01.0__stat__input__rx_bytes              0
# metric__vnf0.vdu01.0__stat__input__rx_packets            0
# metric__vnf0.vdu01.0__stat__input__tx_bytes              0
# metric__vnf0.vdu01.0__stat__input__tx_packets            0
# metric__vnf0.vdu01.0__stat__lo__rx_bytes                 0
# metric__vnf0.vdu01.0__stat__lo__rx_packets               0
# metric__vnf0.vdu01.0__stat__lo__tx_bytes                 0
# metric__vnf0.vdu01.0__stat__lo__tx_packets               0
# metric__vnf0.vdu01.0__stat__output__rx_bytes             0
# metric__vnf0.vdu01.0__stat__output__rx_packets           0
# metric__vnf0.vdu01.0__stat__output__tx_bytes             0
# metric__vnf0.vdu01.0__stat__output__tx_packets           0
# param__func__de.upb.broker-mosquitto.0.1__cpu_bw         0
# param__func__de.upb.broker-mosquitto.0.1__mem_max        0
# dtype: int64

# %%
# getting column names
column_names = dataset_new.columns

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
imputer.fit(dataset_new)
dataset_new = imputer.transform(dataset_new)

# %%
# Converting the NumPy array back to a Pandas DataFrame
dataset_new = pd.DataFrame(dataset_new, columns=column_names)

# Checking for missing values in the Pandas DataFrame
dataset_new.isnull().sum()
# Out:
# metric__mp.input.vdu01.0__malaria_msgs_per_sec         0
# metric__mp.input.vdu01.0__malaria_time_max             0
# metric__mp.input.vdu01.0__malaria_time_mean            0
# metric__mp.input.vdu01.0__malaria_time_min             0
# metric__mp.input.vdu01.0__malaria_time_stddev          0
# metric__mp.input.vdu01.0__malaria_time_total           0
# metric__mp.input.vdu01.0__stat__data__rx_bytes         0
# metric__mp.input.vdu01.0__stat__data__rx_packets       0
# metric__mp.input.vdu01.0__stat__data__tx_bytes         0
# metric__mp.input.vdu01.0__stat__data__tx_packets       0
# metric__mp.input.vdu01.0__stat__eth0__rx_bytes         0
# metric__mp.input.vdu01.0__stat__eth0__rx_packets       0
# metric__mp.input.vdu01.0__stat__lo__rx_bytes           0
# metric__mp.input.vdu01.0__stat__lo__rx_packets         0
# metric__mp.input.vdu01.0__stat__lo__tx_bytes           0
# metric__mp.input.vdu01.0__stat__lo__tx_packets         0
# metric__mp.output.vdu01.0__malaria_flight_time_max     0
# metric__mp.output.vdu01.0__malaria_flight_time_mean    0
# metric__mp.output.vdu01.0__malaria_flight_time_min     0
# metric__mp.output.vdu01.0__malaria_ms_per_msg          0
# metric__mp.output.vdu01.0__malaria_msg_count           0
# metric__mp.output.vdu01.0__malaria_msg_per_sec         0
# metric__mp.output.vdu01.0__malaria_time_total          0
# metric__mp.output.vdu01.0__stat__data__rx_bytes        0
# metric__mp.output.vdu01.0__stat__data__rx_packets      0
# metric__mp.output.vdu01.0__stat__data__tx_bytes        0
# metric__mp.output.vdu01.0__stat__data__tx_packets      0
# metric__mp.output.vdu01.0__stat__eth0__rx_bytes        0
# metric__mp.output.vdu01.0__stat__eth0__rx_packets      0
# metric__mp.output.vdu01.0__stat__lo__rx_bytes          0
# metric__mp.output.vdu01.0__stat__lo__rx_packets        0
# metric__mp.output.vdu01.0__stat__lo__tx_bytes          0
# metric__mp.output.vdu01.0__stat__lo__tx_packets        0
# metric__vnf0.vdu01.0__stat__eth0__rx_bytes             0
# metric__vnf0.vdu01.0__stat__eth0__rx_packets           0
# metric__vnf0.vdu01.0__stat__eth0__tx_bytes             0
# metric__vnf0.vdu01.0__stat__eth0__tx_packets           0
# metric__vnf0.vdu01.0__stat__input__rx_bytes            0
# metric__vnf0.vdu01.0__stat__input__rx_packets          0
# metric__vnf0.vdu01.0__stat__input__tx_bytes            0
# metric__vnf0.vdu01.0__stat__input__tx_packets          0
# metric__vnf0.vdu01.0__stat__lo__rx_bytes               0
# metric__vnf0.vdu01.0__stat__lo__rx_packets             0
# metric__vnf0.vdu01.0__stat__lo__tx_bytes               0
# metric__vnf0.vdu01.0__stat__lo__tx_packets             0
# metric__vnf0.vdu01.0__stat__output__rx_bytes           0
# metric__vnf0.vdu01.0__stat__output__rx_packets         0
# metric__vnf0.vdu01.0__stat__output__tx_bytes           0
# metric__vnf0.vdu01.0__stat__output__tx_packets         0
# param__func__de.upb.broker-mosquitto.0.1__cpu_bw       0
# param__func__de.upb.broker-mosquitto.0.1__mem_max      0
# dtype: int64

# %%
X = dataset_new.iloc[:, :-2].values
y = dataset_new.iloc[:, -2:].values

# %%
print(X)
# Out:
# [[1.44248670e+03 5.59325004e+03 3.41272068e+03 ... 4.11700000e+03
#   1.43050300e+06 4.34300000e+03]
#  [1.41449877e+03 5.97367597e+03 3.75615993e+03 ... 4.19000000e+03
#   1.45962100e+06 4.42300000e+03]
#  [1.44407480e+03 5.53661799e+03 3.31721307e+03 ... 4.12600000e+03
#   1.41640500e+06 4.35500000e+03]
#  ...
#  [3.39133717e+02 4.24869061e+01 2.80383186e+00 ... 1.06210000e+04
#   1.01291299e+08 1.00440000e+04]
#  [3.29418297e+02 4.41689491e+01 3.00378206e+00 ... 1.26210000e+04
#   1.01432771e+08 1.00470000e+04]
#  [3.36934658e+02 4.30510044e+01 2.64275198e+00 ... 1.00050000e+04
#   1.01359133e+08 1.00280000e+04]]

# %%
print(y[:,1])
y[:, 1] = np.where(y[:, 1] == 64, 0, 1)
print(y[:, 1])
# Out:
# [ 64.  64.  64. ... 512. 512. 512.]
# [0. 0. 0. ... 1. 1. 1.]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Separate the two output features
y_train_output1 = y_train[:, 0]  # First column for the output ranging from 0.1 to 1.0
y_train_output2 = y_train[:, 1]  # Second column for binary classification

y_test_output1 = y_test[:, 0]  # First column for the output ranging from 0.1 to 1.0
y_test_output2 = y_test[:, 1]  # Second column for binary classification

# %%
print(y_train_output2)
# Out:
# [1. 0. 0. ... 1. 0. 0.]

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize input features
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %%
print(X_train_normalized)
# Out:
# [[4.30251924e-01 1.36504248e-01 5.60401271e-01 ... 7.13091922e-02
#   7.07006518e-03 5.28276780e-02]
#  [3.41823593e-01 1.77831110e-01 7.80394627e-01 ... 6.61095636e-02
#   1.85143459e-04 3.82568197e-02]
#  [4.28819136e-01 1.30784638e-01 5.25725959e-01 ... 7.03187868e-02
#   6.81689976e-03 5.04324684e-02]
#  ...
#  [4.29267559e-01 1.39803613e-01 5.77468384e-01 ... 8.02228412e-02
#   7.06158714e-03 6.10778443e-02]
#  [3.08506648e-02 1.12010488e-02 3.23613039e-04 ... 4.63819251e-01
#   9.94363574e-01 4.33333333e-01]
#  [3.41701078e-01 1.75613482e-01 7.70027579e-01 ... 6.35097493e-02
#   1.52515840e-04 3.54624085e-02]]

# %%
print(type(y_train_output1))
print(type(y_train_output2))
print(type(y_test_output1))
print(type(y_test_output2))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(X_train_normalized.shape)
print(y_train_output1.shape)
print(y_train_output2.shape)
print(y_test_output1.shape)
print(y_test_output2.shape)
# Out:
# (1280, 49)
# (1280,)
# (1280,)
# (320,)
# (320,)

# %% [markdown]
# ## Building Model

# %%
input_shape = (49,)
inputs = tf.keras.Input(shape=input_shape)
x = tf.keras.layers.Dense(units=64, activation='relu')(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(units=64, activation='relu')(x)
x = tf.keras.layers.Dense(units=32, activation='relu')(x)
output_1 = tf.keras.layers.Dense(units=1, activation='linear', name='output_1')(x)  # Output 1: Regression
output_2 = tf.keras.layers.Dense(units=1, activation='sigmoid', name='output_2')(x)  # Output 2: Classification

model = tf.keras.Model(inputs=inputs, outputs=[output_1, output_2])

# Check the model output names
print("Model Output Names:", model.output_names)
# Out:
# Model Output Names: ['output_1', 'output_2']

# %%
model.compile(
    loss={
        'output_1': 'mean_squared_error',  # Regression loss function
        'output_2': 'binary_crossentropy'  # Binary classification loss function
    },
    optimizer='adam',
    metrics={
        'output_1': ['mae', 'mse'],
        'output_2': 'accuracy'
    }
)

model.fit(X_train_normalized, {'output_1': y_train_output1, 'output_2': y_train_output2},
          validation_data=(X_test_normalized, {'output_1': y_test_output1, 'output_2': y_test_output2}),
          epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 4s 23ms/step - loss: 0.8210 - output_1_loss: 0.1218 - output_2_loss: 0.6992 - output_1_mae: 0.2885 - output_1_mse: 0.1218 - output_2_accuracy: 0.5156 - val_loss: 0.7729 - val_output_1_loss: 0.0823 - val_output_2_loss: 0.6905 - val_output_1_mae: 0.2502 - val_output_1_mse: 0.0823 - val_output_2_accuracy: 0.5344
# Epoch 2/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7721 - output_1_loss: 0.0800 - output_2_loss: 0.6921 - output_1_mae: 0.2425 - output_1_mse: 0.0800 - output_2_accuracy: 0.5219 - val_loss: 0.7682 - val_output_1_loss: 0.0777 - val_output_2_loss: 0.6905 - val_output_1_mae: 0.2432 - val_output_1_mse: 0.0777 - val_output_2_accuracy: 0.5312
# Epoch 3/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7668 - output_1_loss: 0.0746 - output_2_loss: 0.6922 - output_1_mae: 0.2360 - output_1_mse: 0.0746 - output_2_accuracy: 0.5148 - val_loss: 0.7691 - val_output_1_loss: 0.0783 - val_output_2_loss: 0.6908 - val_output_1_mae: 0.2423 - val_output_1_mse: 0.0783 - val_output_2_accuracy: 0.5250
# Epoch 4/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7648 - output_1_loss: 0.0728 - output_2_loss: 0.6921 - output_1_mae: 0.2323 - output_1_mse: 0.0728 - output_2_accuracy: 0.5297 - val_loss: 0.7626 - val_output_1_loss: 0.0755 - val_output_2_loss: 0.6871 - val_output_1_mae: 0.2382 - val_output_1_mse: 0.0755 - val_output_2_accuracy: 0.5719
# Epoch 5/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7629 - output_1_loss: 0.0729 - output_2_loss: 0.6900 - output_1_mae: 0.2334 - output_1_mse: 0.0729 - output_2_accuracy: 0.5273 - val_loss: 0.7560 - val_output_1_loss: 0.0678 - val_output_2_loss: 0.6882 - val_output_1_mae: 0.2287 - val_output_1_mse: 0.0678 - val_output_2_accuracy: 0.5656
# Epoch 6/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7606 - output_1_loss: 0.0695 - output_2_loss: 0.6911 - output_1_mae: 0.2277 - output_1_mse: 0.0695 - output_2_accuracy: 0.5328 - val_loss: 0.7537 - val_output_1_loss: 0.0675 - val_output_2_loss: 0.6863 - val_output_1_mae: 0.2286 - val_output_1_mse: 0.0675 - val_output_2_accuracy: 0.5688
# Epoch 7/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7553 - output_1_loss: 0.0684 - output_2_loss: 0.6869 - output_1_mae: 0.2250 - output_1_mse: 0.0684 - output_2_accuracy: 0.5531 - val_loss: 0.7565 - val_output_1_loss: 0.0712 - val_output_2_loss: 0.6853 - val_output_1_mae: 0.2330 - val_output_1_mse: 0.0712 - val_output_2_accuracy: 0.5719
# Epoch 8/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7587 - output_1_loss: 0.0696 - output_2_loss: 0.6892 - output_1_mae: 0.2266 - output_1_mse: 0.0696 - output_2_accuracy: 0.5406 - val_loss: 0.7545 - val_output_1_loss: 0.0647 - val_output_2_loss: 0.6898 - val_output_1_mae: 0.2231 - val_output_1_mse: 0.0647 - val_output_2_accuracy: 0.5594
# Epoch 9/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7548 - output_1_loss: 0.0675 - output_2_loss: 0.6873 - output_1_mae: 0.2238 - output_1_mse: 0.0675 - output_2_accuracy: 0.5594 - val_loss: 0.7581 - val_output_1_loss: 0.0694 - val_output_2_loss: 0.6887 - val_output_1_mae: 0.2303 - val_output_1_mse: 0.0694 - val_output_2_accuracy: 0.5625
# Epoch 10/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7516 - output_1_loss: 0.0669 - output_2_loss: 0.6848 - output_1_mae: 0.2222 - output_1_mse: 0.0669 - output_2_accuracy: 0.5602 - val_loss: 0.7540 - val_output_1_loss: 0.0637 - val_output_2_loss: 0.6903 - val_output_1_mae: 0.2208 - val_output_1_mse: 0.0637 - val_output_2_accuracy: 0.5688
# Epoch 11/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7499 - output_1_loss: 0.0649 - output_2_loss: 0.6850 - output_1_mae: 0.2203 - output_1_mse: 0.0649 - output_2_accuracy: 0.5570 - val_loss: 0.7530 - val_output_1_loss: 0.0630 - val_output_2_loss: 0.6901 - val_output_1_mae: 0.2192 - val_output_1_mse: 0.0630 - val_output_2_accuracy: 0.5750
# Epoch 12/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7548 - output_1_loss: 0.0671 - output_2_loss: 0.6877 - output_1_mae: 0.2231 - output_1_mse: 0.0671 - output_2_accuracy: 0.5437 - val_loss: 0.7548 - val_output_1_loss: 0.0637 - val_output_2_loss: 0.6911 - val_output_1_mae: 0.2194 - val_output_1_mse: 0.0637 - val_output_2_accuracy: 0.5750
# Epoch 13/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7481 - output_1_loss: 0.0641 - output_2_loss: 0.6841 - output_1_mae: 0.2181 - output_1_mse: 0.0641 - output_2_accuracy: 0.5750 - val_loss: 0.7582 - val_output_1_loss: 0.0666 - val_output_2_loss: 0.6916 - val_output_1_mae: 0.2242 - val_output_1_mse: 0.0666 - val_output_2_accuracy: 0.5625
# Epoch 14/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7454 - output_1_loss: 0.0643 - output_2_loss: 0.6811 - output_1_mae: 0.2179 - output_1_mse: 0.0643 - output_2_accuracy: 0.5734 - val_loss: 0.7576 - val_output_1_loss: 0.0643 - val_output_2_loss: 0.6933 - val_output_1_mae: 0.2200 - val_output_1_mse: 0.0643 - val_output_2_accuracy: 0.5781
# Epoch 15/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7487 - output_1_loss: 0.0641 - output_2_loss: 0.6846 - output_1_mae: 0.2179 - output_1_mse: 0.0641 - output_2_accuracy: 0.5602 - val_loss: 0.7506 - val_output_1_loss: 0.0606 - val_output_2_loss: 0.6900 - val_output_1_mae: 0.2141 - val_output_1_mse: 0.0606 - val_output_2_accuracy: 0.5562
# Epoch 16/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7481 - output_1_loss: 0.0622 - output_2_loss: 0.6859 - output_1_mae: 0.2151 - output_1_mse: 0.0622 - output_2_accuracy: 0.5516 - val_loss: 0.7570 - val_output_1_loss: 0.0660 - val_output_2_loss: 0.6910 - val_output_1_mae: 0.2219 - val_output_1_mse: 0.0660 - val_output_2_accuracy: 0.5688
# Epoch 17/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7472 - output_1_loss: 0.0650 - output_2_loss: 0.6822 - output_1_mae: 0.2173 - output_1_mse: 0.0650 - output_2_accuracy: 0.5695 - val_loss: 0.7494 - val_output_1_loss: 0.0588 - val_output_2_loss: 0.6906 - val_output_1_mae: 0.2089 - val_output_1_mse: 0.0588 - val_output_2_accuracy: 0.5562
# Epoch 18/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7429 - output_1_loss: 0.0624 - output_2_loss: 0.6805 - output_1_mae: 0.2139 - output_1_mse: 0.0624 - output_2_accuracy: 0.5602 - val_loss: 0.7519 - val_output_1_loss: 0.0577 - val_output_2_loss: 0.6941 - val_output_1_mae: 0.2071 - val_output_1_mse: 0.0577 - val_output_2_accuracy: 0.5656
# Epoch 19/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7422 - output_1_loss: 0.0610 - output_2_loss: 0.6812 - output_1_mae: 0.2115 - output_1_mse: 0.0610 - output_2_accuracy: 0.5773 - val_loss: 0.7556 - val_output_1_loss: 0.0594 - val_output_2_loss: 0.6962 - val_output_1_mae: 0.2100 - val_output_1_mse: 0.0594 - val_output_2_accuracy: 0.5688
# Epoch 20/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7469 - output_1_loss: 0.0625 - output_2_loss: 0.6844 - output_1_mae: 0.2133 - output_1_mse: 0.0625 - output_2_accuracy: 0.5641 - val_loss: 0.7533 - val_output_1_loss: 0.0599 - val_output_2_loss: 0.6935 - val_output_1_mae: 0.2087 - val_output_1_mse: 0.0599 - val_output_2_accuracy: 0.5594
# Epoch 21/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7416 - output_1_loss: 0.0599 - output_2_loss: 0.6817 - output_1_mae: 0.2093 - output_1_mse: 0.0599 - output_2_accuracy: 0.5609 - val_loss: 0.7537 - val_output_1_loss: 0.0601 - val_output_2_loss: 0.6936 - val_output_1_mae: 0.2058 - val_output_1_mse: 0.0601 - val_output_2_accuracy: 0.5406
# Epoch 22/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7408 - output_1_loss: 0.0607 - output_2_loss: 0.6800 - output_1_mae: 0.2080 - output_1_mse: 0.0607 - output_2_accuracy: 0.5648 - val_loss: 0.7565 - val_output_1_loss: 0.0637 - val_output_2_loss: 0.6928 - val_output_1_mae: 0.2173 - val_output_1_mse: 0.0637 - val_output_2_accuracy: 0.5469
# Epoch 23/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7420 - output_1_loss: 0.0624 - output_2_loss: 0.6796 - output_1_mae: 0.2123 - output_1_mse: 0.0624 - output_2_accuracy: 0.5672 - val_loss: 0.7516 - val_output_1_loss: 0.0593 - val_output_2_loss: 0.6923 - val_output_1_mae: 0.2067 - val_output_1_mse: 0.0593 - val_output_2_accuracy: 0.5531
# Epoch 24/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7423 - output_1_loss: 0.0606 - output_2_loss: 0.6817 - output_1_mae: 0.2105 - output_1_mse: 0.0606 - output_2_accuracy: 0.5656 - val_loss: 0.7595 - val_output_1_loss: 0.0624 - val_output_2_loss: 0.6971 - val_output_1_mae: 0.2116 - val_output_1_mse: 0.0624 - val_output_2_accuracy: 0.5625
# Epoch 25/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7395 - output_1_loss: 0.0601 - output_2_loss: 0.6795 - output_1_mae: 0.2082 - output_1_mse: 0.0601 - output_2_accuracy: 0.5766 - val_loss: 0.7471 - val_output_1_loss: 0.0559 - val_output_2_loss: 0.6912 - val_output_1_mae: 0.2007 - val_output_1_mse: 0.0559 - val_output_2_accuracy: 0.5562
# Epoch 26/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7366 - output_1_loss: 0.0588 - output_2_loss: 0.6778 - output_1_mae: 0.2057 - output_1_mse: 0.0588 - output_2_accuracy: 0.5695 - val_loss: 0.7544 - val_output_1_loss: 0.0597 - val_output_2_loss: 0.6948 - val_output_1_mae: 0.2047 - val_output_1_mse: 0.0597 - val_output_2_accuracy: 0.5656
# Epoch 27/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7362 - output_1_loss: 0.0591 - output_2_loss: 0.6770 - output_1_mae: 0.2069 - output_1_mse: 0.0591 - output_2_accuracy: 0.5711 - val_loss: 0.7498 - val_output_1_loss: 0.0573 - val_output_2_loss: 0.6926 - val_output_1_mae: 0.2054 - val_output_1_mse: 0.0573 - val_output_2_accuracy: 0.5469
# Epoch 28/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7338 - output_1_loss: 0.0601 - output_2_loss: 0.6737 - output_1_mae: 0.2068 - output_1_mse: 0.0601 - output_2_accuracy: 0.5797 - val_loss: 0.7579 - val_output_1_loss: 0.0605 - val_output_2_loss: 0.6975 - val_output_1_mae: 0.2107 - val_output_1_mse: 0.0605 - val_output_2_accuracy: 0.5562
# Epoch 29/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7352 - output_1_loss: 0.0596 - output_2_loss: 0.6757 - output_1_mae: 0.2062 - output_1_mse: 0.0596 - output_2_accuracy: 0.5750 - val_loss: 0.7512 - val_output_1_loss: 0.0594 - val_output_2_loss: 0.6918 - val_output_1_mae: 0.2041 - val_output_1_mse: 0.0594 - val_output_2_accuracy: 0.5406
# Epoch 30/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7343 - output_1_loss: 0.0602 - output_2_loss: 0.6741 - output_1_mae: 0.2054 - output_1_mse: 0.0602 - output_2_accuracy: 0.5750 - val_loss: 0.7506 - val_output_1_loss: 0.0578 - val_output_2_loss: 0.6929 - val_output_1_mae: 0.2010 - val_output_1_mse: 0.0578 - val_output_2_accuracy: 0.5500
# Epoch 31/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7327 - output_1_loss: 0.0600 - output_2_loss: 0.6727 - output_1_mae: 0.2067 - output_1_mse: 0.0600 - output_2_accuracy: 0.5836 - val_loss: 0.7536 - val_output_1_loss: 0.0578 - val_output_2_loss: 0.6959 - val_output_1_mae: 0.2061 - val_output_1_mse: 0.0578 - val_output_2_accuracy: 0.5437
# Epoch 32/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7304 - output_1_loss: 0.0573 - output_2_loss: 0.6731 - output_1_mae: 0.2032 - output_1_mse: 0.0573 - output_2_accuracy: 0.5820 - val_loss: 0.7529 - val_output_1_loss: 0.0570 - val_output_2_loss: 0.6959 - val_output_1_mae: 0.2016 - val_output_1_mse: 0.0570 - val_output_2_accuracy: 0.5469
# Epoch 33/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7329 - output_1_loss: 0.0588 - output_2_loss: 0.6741 - output_1_mae: 0.2054 - output_1_mse: 0.0588 - output_2_accuracy: 0.5797 - val_loss: 0.7556 - val_output_1_loss: 0.0575 - val_output_2_loss: 0.6981 - val_output_1_mae: 0.2026 - val_output_1_mse: 0.0575 - val_output_2_accuracy: 0.5531
# Epoch 34/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7339 - output_1_loss: 0.0600 - output_2_loss: 0.6740 - output_1_mae: 0.2080 - output_1_mse: 0.0600 - output_2_accuracy: 0.5828 - val_loss: 0.7559 - val_output_1_loss: 0.0608 - val_output_2_loss: 0.6951 - val_output_1_mae: 0.2089 - val_output_1_mse: 0.0608 - val_output_2_accuracy: 0.5500
# Epoch 35/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.7338 - output_1_loss: 0.0594 - output_2_loss: 0.6744 - output_1_mae: 0.2072 - output_1_mse: 0.0594 - output_2_accuracy: 0.5813 - val_loss: 0.7527 - val_output_1_loss: 0.0592 - val_output_2_loss: 0.6934 - val_output_1_mae: 0.2071 - val_output_1_mse: 0.0592 - val_output_2_accuracy: 0.5594
# Epoch 36/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7316 - output_1_loss: 0.0574 - output_2_loss: 0.6741 - output_1_mae: 0.2026 - output_1_mse: 0.0574 - output_2_accuracy: 0.5695 - val_loss: 0.7552 - val_output_1_loss: 0.0559 - val_output_2_loss: 0.6994 - val_output_1_mae: 0.2024 - val_output_1_mse: 0.0559 - val_output_2_accuracy: 0.5344
# Epoch 37/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7273 - output_1_loss: 0.0584 - output_2_loss: 0.6690 - output_1_mae: 0.2047 - output_1_mse: 0.0584 - output_2_accuracy: 0.5820 - val_loss: 0.7593 - val_output_1_loss: 0.0578 - val_output_2_loss: 0.7015 - val_output_1_mae: 0.2050 - val_output_1_mse: 0.0578 - val_output_2_accuracy: 0.5344
# Epoch 38/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7301 - output_1_loss: 0.0588 - output_2_loss: 0.6713 - output_1_mae: 0.2049 - output_1_mse: 0.0588 - output_2_accuracy: 0.5836 - val_loss: 0.7559 - val_output_1_loss: 0.0584 - val_output_2_loss: 0.6975 - val_output_1_mae: 0.2045 - val_output_1_mse: 0.0584 - val_output_2_accuracy: 0.5469
# Epoch 39/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7286 - output_1_loss: 0.0578 - output_2_loss: 0.6709 - output_1_mae: 0.2028 - output_1_mse: 0.0578 - output_2_accuracy: 0.5875 - val_loss: 0.7531 - val_output_1_loss: 0.0573 - val_output_2_loss: 0.6959 - val_output_1_mae: 0.2041 - val_output_1_mse: 0.0573 - val_output_2_accuracy: 0.5406
# Epoch 40/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7262 - output_1_loss: 0.0567 - output_2_loss: 0.6695 - output_1_mae: 0.1997 - output_1_mse: 0.0567 - output_2_accuracy: 0.5758 - val_loss: 0.7539 - val_output_1_loss: 0.0594 - val_output_2_loss: 0.6944 - val_output_1_mae: 0.2049 - val_output_1_mse: 0.0594 - val_output_2_accuracy: 0.5375
# Epoch 41/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7200 - output_1_loss: 0.0559 - output_2_loss: 0.6642 - output_1_mae: 0.1990 - output_1_mse: 0.0559 - output_2_accuracy: 0.5891 - val_loss: 0.7555 - val_output_1_loss: 0.0572 - val_output_2_loss: 0.6983 - val_output_1_mae: 0.2036 - val_output_1_mse: 0.0572 - val_output_2_accuracy: 0.5344
# Epoch 42/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7279 - output_1_loss: 0.0572 - output_2_loss: 0.6707 - output_1_mae: 0.2023 - output_1_mse: 0.0572 - output_2_accuracy: 0.5758 - val_loss: 0.7568 - val_output_1_loss: 0.0591 - val_output_2_loss: 0.6977 - val_output_1_mae: 0.2049 - val_output_1_mse: 0.0591 - val_output_2_accuracy: 0.5531
# Epoch 43/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7244 - output_1_loss: 0.0575 - output_2_loss: 0.6669 - output_1_mae: 0.2009 - output_1_mse: 0.0575 - output_2_accuracy: 0.5875 - val_loss: 0.7561 - val_output_1_loss: 0.0576 - val_output_2_loss: 0.6985 - val_output_1_mae: 0.2062 - val_output_1_mse: 0.0576 - val_output_2_accuracy: 0.5469
# Epoch 44/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7234 - output_1_loss: 0.0576 - output_2_loss: 0.6658 - output_1_mae: 0.2016 - output_1_mse: 0.0576 - output_2_accuracy: 0.5758 - val_loss: 0.7576 - val_output_1_loss: 0.0612 - val_output_2_loss: 0.6964 - val_output_1_mae: 0.2107 - val_output_1_mse: 0.0612 - val_output_2_accuracy: 0.5594
# Epoch 45/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7210 - output_1_loss: 0.0574 - output_2_loss: 0.6636 - output_1_mae: 0.2032 - output_1_mse: 0.0574 - output_2_accuracy: 0.6016 - val_loss: 0.7519 - val_output_1_loss: 0.0573 - val_output_2_loss: 0.6946 - val_output_1_mae: 0.2025 - val_output_1_mse: 0.0573 - val_output_2_accuracy: 0.5344
# Epoch 46/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7178 - output_1_loss: 0.0550 - output_2_loss: 0.6629 - output_1_mae: 0.1978 - output_1_mse: 0.0550 - output_2_accuracy: 0.5969 - val_loss: 0.7573 - val_output_1_loss: 0.0585 - val_output_2_loss: 0.6988 - val_output_1_mae: 0.2017 - val_output_1_mse: 0.0585 - val_output_2_accuracy: 0.5281
# Epoch 47/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7249 - output_1_loss: 0.0568 - output_2_loss: 0.6681 - output_1_mae: 0.2005 - output_1_mse: 0.0568 - output_2_accuracy: 0.5867 - val_loss: 0.7519 - val_output_1_loss: 0.0595 - val_output_2_loss: 0.6924 - val_output_1_mae: 0.2060 - val_output_1_mse: 0.0595 - val_output_2_accuracy: 0.5562
# Epoch 48/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7182 - output_1_loss: 0.0563 - output_2_loss: 0.6619 - output_1_mae: 0.1996 - output_1_mse: 0.0563 - output_2_accuracy: 0.5992 - val_loss: 0.7565 - val_output_1_loss: 0.0568 - val_output_2_loss: 0.6997 - val_output_1_mae: 0.2005 - val_output_1_mse: 0.0568 - val_output_2_accuracy: 0.5469
# Epoch 49/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7165 - output_1_loss: 0.0587 - output_2_loss: 0.6578 - output_1_mae: 0.2036 - output_1_mse: 0.0587 - output_2_accuracy: 0.5828 - val_loss: 0.7659 - val_output_1_loss: 0.0620 - val_output_2_loss: 0.7039 - val_output_1_mae: 0.2101 - val_output_1_mse: 0.0620 - val_output_2_accuracy: 0.5281
# Epoch 50/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.7201 - output_1_loss: 0.0565 - output_2_loss: 0.6636 - output_1_mae: 0.1998 - output_1_mse: 0.0565 - output_2_accuracy: 0.5805 - val_loss: 0.7626 - val_output_1_loss: 0.0594 - val_output_2_loss: 0.7032 - val_output_1_mae: 0.2060 - val_output_1_mse: 0.0594 - val_output_2_accuracy: 0.5562

# %%
# Predict on the test data
y_pred_output1, y_pred_output2 = model.predict(X_test_normalized)

# For output_1 (Regression)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae_output1 = mean_absolute_error(y_test_output1, y_pred_output1)
mse_output1 = mean_squared_error(y_test_output1, y_pred_output1)
r2_output1 = r2_score(y_test_output1, y_pred_output1)

print("Output 1 - Mean Absolute Error:", mae_output1)
print("Output 1 - Mean Squared Error:", mse_output1)
print("Output 1 - R^2 Score:", r2_output1)



# For output_2 (Classification)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Convert probabilities to binary predictions (0 or 1) for classification
y_pred_output2_binary = (y_pred_output2 > 0.5).astype(int)

accuracy_output2 = accuracy_score(y_test_output2, y_pred_output2_binary)
conf_matrix_output2 = confusion_matrix(y_test_output2, y_pred_output2_binary)
classification_rep_output2 = classification_report(y_test_output2, y_pred_output2_binary)

print("Output 2 - Accuracy:", accuracy_output2)
print("Output 2 - Confusion Matrix:")
print(conf_matrix_output2)
print("Output 2 - Classification Report:")
print(classification_rep_output2)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Output 1 - Mean Absolute Error: 0.20604685835540293
# Output 1 - Mean Squared Error: 0.05942040087600596
# Output 1 - R^2 Score: 0.30995524376905126
# Output 2 - Accuracy: 0.55625
# Output 2 - Confusion Matrix:
# [[ 71  96]
#  [ 46 107]]
# Output 2 - Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.43      0.50       167
#          1.0       0.53      0.70      0.60       153
#
#     accuracy                           0.56       320
#    macro avg       0.57      0.56      0.55       320
# weighted avg       0.57      0.56      0.55       320

# %%
y_test1 = y_test[:,0]

rounded_y_pred = y_pred_output1.reshape(len(y_pred_output1), 1).round(1)

# Reshape y_test1 to a column vector
y_test1_reshaped = y_test1.reshape(len(y_test1), 1)

# Concatenate both arrays side by side (along axis 1)
result = np.concatenate((rounded_y_pred, y_test1_reshaped), axis=1)
np.set_printoptions(precision=1)
print(result)
# Out:
# [[0.4 0.7]
#  [0.4 0.3]
#  [0.7 1. ]
#  [0.5 0.6]
#  [0.5 0.7]
#  [0.5 0.3]
#  [0.4 0.7]
#  [0.4 0.5]
#  [0.8 0.9]
#  [0.4 0.1]
#  [0.5 0.4]
#  [0.5 0.5]
#  [0.6 1. ]
#  [0.4 0.1]
#  [0.5 0.2]
#  [0.5 0.1]
#  [0.5 0.7]
#  [0.5 0.2]
#  [0.7 0.9]
#  [0.5 0.1]
#  [0.4 0.6]
#  [0.4 0.1]
#  [0.4 0.3]
#  [0.5 0.8]
#  [0.4 0.7]
#  [0.3 0.4]
#  [0.4 0.7]
#  [0.5 0.2]
#  [0.6 1. ]
#  [0.6 0.9]
#  [0.9 0.9]
#  [0.4 0.3]
#  [0.5 0.7]
#  [0.5 0.7]
#  [0.5 0.4]
#  [0.5 0.2]
#  [0.6 1. ]
#  [0.9 0.9]
#  [0.5 0.3]
#  [0.5 0.1]
#  [0.9 1. ]
#  [0.5 0.8]
#  [0.5 0.3]
#  [0.9 0.9]
#  [0.5 0.8]
#  [0.5 0.4]
#  [0.4 0.5]
#  [0.5 0.9]
#  [0.5 0.5]
#  [0.4 0.8]
#  [0.6 0.7]
#  [0.4 0.3]
#  [0.6 0.8]
#  [0.3 0.1]
#  [0.4 0.7]
#  [0.5 0.5]
#  [0.6 0.9]
#  [0.5 0.4]
#  [0.5 0.1]
#  [1.  1. ]
#  [0.8 0.6]
#  [0.5 0.9]
#  [0.7 0.9]
#  [0.8 1. ]
#  [0.5 0.6]
#  [0.4 0.1]
#  [0.9 1. ]
#  [0.6 0.5]
#  [1.2 1. ]
#  [0.4 0.4]
#  [0.5 0.5]
#  [0.6 0.2]
#  [0.4 0.1]
#  [0.5 0.8]
#  [0.2 0.1]
#  [0.4 0.5]
#  [0.6 0.9]
#  [0.5 0.2]
#  [0.5 0.5]
#  [0.4 0.1]
#  [0.5 0.8]
#  [0.4 0.8]
#  [0.5 0.6]
#  [0.4 0.7]
#  [0.5 0.3]
#  [0.5 0.8]
#  [0.5 0.2]
#  [0.4 0.4]
#  [0.4 0.5]
#  [0.4 0.1]
#  [0.5 0.8]
#  [0.5 0.8]
#  [0.7 0.8]
#  [0.4 0.4]
#  [0.6 1. ]
#  [0.5 0.8]
#  [0.9 0.9]
#  [0.5 0.2]
#  [0.4 0.6]
#  [0.5 0.3]
#  [0.9 1. ]
#  [0.6 1. ]
#  [0.5 0.2]
#  [0.5 0.5]
#  [0.7 0.7]
#  [1.  0.9]
#  [0.3 0.1]
#  [0.9 1. ]
#  [0.5 0.2]
#  [0.5 0.4]
#  [0.5 0.3]
#  [0.6 1. ]
#  [0.4 0.4]
#  [0.4 0.8]
#  [0.5 0.4]
#  [0.7 0.5]
#  [0.4 0.3]
#  [0.7 0.8]
#  [0.4 0.2]
#  [0.6 0.8]
#  [1.  0.9]
#  [0.5 0.9]
#  [0.5 0.5]
#  [0.4 0.2]
#  [0.4 0.1]
#  [0.5 0.4]
#  [0.4 0.4]
#  [0.4 0.6]
#  [0.4 0.6]
#  [0.4 0.4]
#  [0.5 0.2]
#  [0.5 0.3]
#  [0.5 0.3]
#  [0.4 0.8]
#  [0.5 0.4]
#  [0.6 0.8]
#  [0.6 0.6]
#  [0.5 0.5]
#  [0.5 0.9]
#  [0.5 0.8]
#  [0.5 0.9]
#  [0.5 0.6]
#  [0.5 0.4]
#  [0.4 0.8]
#  [0.5 0.2]
#  [0.6 1. ]
#  [0.8 0.7]
#  [0.5 0.6]
#  [0.5 0.3]
#  [0.5 0.7]
#  [0.5 0.2]
#  [0.6 0.2]
#  [0.6 1. ]
#  [0.5 0.4]
#  [0.6 0.7]
#  [1.  0.9]
#  [0.4 0.1]
#  [0.5 0.5]
#  [0.5 0.5]
#  [0.6 0.9]
#  [1.  1. ]
#  [0.3 0.6]
#  [0.4 0.1]
#  [0.4 0.2]
#  [0.4 0.5]
#  [0.4 0.4]
#  [0.6 0.2]
#  [0.8 0.9]
#  [0.5 0.7]
#  [1.  1. ]
#  [0.9 1. ]
#  [0.5 0.3]
#  [0.5 0.7]
#  [0.4 0.1]
#  [0.5 0.8]
#  [0.5 0.3]
#  [0.4 0.8]
#  [0.5 0.2]
#  [0.5 0.7]
#  [0.5 1. ]
#  [0.4 0.7]
#  [1.  0.9]
#  [0.5 0.8]
#  [0.5 0.8]
#  [0.5 0.1]
#  [0.5 0.2]
#  [0.6 0.9]
#  [0.5 0.5]
#  [0.5 0.2]
#  [0.5 0.5]
#  [0.4 0.5]
#  [0.5 0.2]
#  [0.8 0.9]
#  [0.5 0.4]
#  [0.4 0.7]
#  [0.4 0.2]
#  [0.5 0.4]
#  [0.5 0.5]
#  [0.5 0.3]
#  [0.4 0.2]
#  [0.4 0.2]
#  [0.4 0.1]
#  [0.5 0.6]
#  [1.  1. ]
#  [0.4 0.3]
#  [0.5 0.3]
#  [0.6 1. ]
#  [0.4 0.1]
#  [0.6 0.9]
#  [0.7 0.8]
#  [0.4 0.4]
#  [0.9 1. ]
#  [0.3 0.5]
#  [0.5 0.3]
#  [0.4 0.1]
#  [0.5 0.3]
#  [0.3 0.1]
#  [0.5 0.8]
#  [0.3 0.4]
#  [0.7 0.5]
#  [0.9 0.6]
#  [0.5 0.2]
#  [0.4 0.1]
#  [0.6 1. ]
#  [0.5 0.7]
#  [0.4 0.5]
#  [0.5 0.2]
#  [0.5 0.8]
#  [0.4 0.6]
#  [0.5 0.6]
#  [0.5 0.4]
#  [0.4 0.1]
#  [0.5 0.7]
#  [0.4 0.3]
#  [0.5 0.7]
#  [0.7 0.7]
#  [0.7 0.9]
#  [0.4 0.6]
#  [0.5 1. ]
#  [0.6 1. ]
#  [0.5 0.8]
#  [0.5 0.3]
#  [0.4 0.5]
#  [0.7 0.8]
#  [0.4 0.7]
#  [0.3 0.2]
#  [0.6 0.9]
#  [0.5 0.5]
#  [1.  0.6]
#  [1.  1. ]
#  [0.9 1. ]
#  [0.5 0.7]
#  [0.5 0.5]
#  [0.7 1. ]
#  [0.5 0.7]
#  [0.4 0.4]
#  [0.3 0.1]
#  [0.4 0.2]
#  [0.5 0.7]
#  [0.7 0.7]
#  [0.5 0.3]
#  [0.4 0.5]
#  [0.5 0.6]
#  [0.5 0.1]
#  [0.5 0.4]
#  [0.5 0.5]
#  [0.5 0.7]
#  [0.5 0.2]
#  [0.5 0.2]
#  [0.5 0.5]
#  [0.5 0.5]
#  [0.5 0.8]
#  [0.9 1. ]
#  [0.4 0.1]
#  [0.6 0.9]
#  [0.3 0.1]
#  [0.9 1. ]
#  [0.6 0.4]
#  [0.5 0.4]
#  [0.4 0.8]
#  [0.7 1. ]
#  [0.4 0.4]
#  [0.4 0.3]
#  [0.4 0.9]
#  [0.5 0.1]
#  [0.3 0.8]
#  [0.4 0.5]
#  [0.5 0.6]
#  [0.9 1. ]
#  [0.4 0.8]
#  [0.4 0.7]
#  [0.5 0.8]
#  [0.5 0.8]
#  [0.7 0.4]
#  [0.5 0.8]
#  [0.4 0.2]
#  [0.5 0.1]
#  [0.5 0.5]
#  [0.6 0.2]
#  [0.3 0.5]
#  [1.  0.2]
#  [0.5 0.4]
#  [0.4 0.3]
#  [0.6 0.8]
#  [0.5 0.5]
#  [0.5 0.9]
#  [0.5 0.5]
#  [0.7 0.7]
#  [0.3 0.1]
#  [0.9 0.2]
#  [0.4 0.1]
#  [0.9 0.9]
#  [0.3 0.6]
#  [0.5 0.8]
#  [0.6 0.9]
#  [0.5 0.4]
#  [0.4 0.1]
#  [0.9 1. ]
#  [0.5 0.4]
#  [0.7 0.9]]

# %% [markdown]
# ## K-fold Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


def gelu_activation(x):
    return 0.5 * x * (1 + tf.keras.activations.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * tf.keras.backend.pow(x, 3))))



num_folds = 5

# Initialize lists to store the evaluation metrics for each fold
mse_output1_list = []
accuracy_output2_list = []

# Create the KFold object
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)


# Create the model
input_shape = (49,)
inputs = tf.keras.Input(shape=input_shape)
x = tf.keras.layers.Dense(units=256, activation='relu')(inputs)  # GELU activation
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(units=256, activation='relu')(x)  # GELU activation
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(units=256, activation='relu')(x)  # GELU activation
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(units=128, activation='relu')(x)  # GELU activation
   

output_1 = tf.keras.layers.Dense(units=1, activation='linear', name='output_1')(x)  # Output 1: Regression
output_2 = tf.keras.layers.Dense(units=1, activation='sigmoid', name='output_2')(x)  # Output 2: Classification

model = tf.keras.Model(inputs=inputs, outputs=[output_1, output_2])

# Perform 5-fold cross-validation
for fold, (train_indices, val_indices) in enumerate(kfold.split(X_train_normalized)):
    print(f"Fold {fold+1}/{num_folds}")
    
    # Split the data into training and validation sets for this fold
    X_train_fold = X_train_normalized[train_indices]
    X_val_fold = X_train_normalized[val_indices]
    y_train_output1_fold = y_train_output1[train_indices]
    y_train_output2_fold = y_train_output2[train_indices]
    y_val_output1_fold = y_train_output1[val_indices]
    y_val_output2_fold = y_train_output2[val_indices]
    
    
    # Compile the model
    model.compile(
        loss={
            'output_1': 'mean_squared_error',  # Regression loss function
            'output_2': 'binary_crossentropy'  # Binary classification loss function
        },
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        metrics={
            'output_1': ['mae', 'mse'],
            'output_2': 'accuracy'
        }
    )
    

    # Train the model
    model.fit(X_train_fold, {'output_1': y_train_output1_fold, 'output_2': y_train_output2_fold},
          epochs=150, batch_size=128, verbose=0)

    
    # Evaluate the model on validation data for this fold
    results = model.evaluate(X_val_fold, {'output_1': y_val_output1_fold, 'output_2': y_val_output2_fold})
    
    mse_output1_list.append(results[2])  # Index 2 corresponds to MSE for 'output_1'
    accuracy_output2_list.append(results[5])  # Index 5 corresponds to accuracy for 'output_2'
# Out:
# Fold 1/5
# 8/8 [==============================] - 1s 6ms/step - loss: 0.9912 - output_1_loss: 0.0763 - output_2_loss: 0.9149 - output_1_mae: 0.2282 - output_1_mse: 0.0763 - output_2_accuracy: 0.5469
# Fold 2/5
# 8/8 [==============================] - 1s 5ms/step - loss: 1.2029 - output_1_loss: 0.0580 - output_2_loss: 1.1448 - output_1_mae: 0.1998 - output_1_mse: 0.0580 - output_2_accuracy: 0.5781
# Fold 3/5
# 8/8 [==============================] - 1s 5ms/step - loss: 1.0967 - output_1_loss: 0.0606 - output_2_loss: 1.0361 - output_1_mae: 0.2006 - output_1_mse: 0.0606 - output_2_accuracy: 0.6211
# Fold 4/5
# 8/8 [==============================] - 1s 5ms/step - loss: 0.7080 - output_1_loss: 0.0538 - output_2_loss: 0.6542 - output_1_mae: 0.1907 - output_1_mse: 0.0538 - output_2_accuracy: 0.7422
# Fold 5/5
# 8/8 [==============================] - 1s 5ms/step - loss: 0.5954 - output_1_loss: 0.0530 - output_2_loss: 0.5424 - output_1_mae: 0.1802 - output_1_mse: 0.0530 - output_2_accuracy: 0.7734

# %%
# Calculate the mean and standard deviation of evaluation metrics across all folds
mean_mse_output1 = np.mean(mse_output1_list)
mean_accuracy_output2 = np.mean(accuracy_output2_list)

std_mse_output1 = np.std(mse_output1_list)
std_accuracy_output2 = np.std(accuracy_output2_list)

# For regression task (output_1) - Calculate R-squared (R^2) score
y_true_output1 = np.concatenate([y_train_output1, y_test_output1])
y_pred_output1 = model.predict(np.concatenate([X_train_normalized, X_test_normalized]))[0]
r2_output1 = r2_score(y_true_output1, y_pred_output1)

print("Mean MSE (Output 1):", mean_mse_output1)
print("Mean Accuracy (Output 2):", mean_accuracy_output2)

print("Standard Deviation MSE (Output 1):", std_mse_output1)
print("Standard Deviation Accuracy (Output 2):", std_accuracy_output2)

print("R^2 Score (Output 1 - Regression):", r2_output1)
# Out:
# 50/50 [==============================] - 0s 4ms/step
# Mean MSE (Output 1): 0.8584982395172119
# Mean Accuracy (Output 2): 0.65234375
# Standard Deviation MSE (Output 1): 0.22730720955898134
# Standard Deviation Accuracy (Output 2): 0.08982676469878006
# R^2 Score (Output 1 - Regression): 0.5217515070315015

# %%
# 1. Compare Regression Output with Original Test Values

# Predict using the trained model on the test data for the regression output (output_1)
y_pred_output1_test = model.predict(X_test_normalized)[0]

# Reshape the predictions and original test values to match for comparison
y_pred_output1_test = y_pred_output1_test.flatten()

# Convert both arrays to the same data type (e.g., float64) for comparison
y_test_output1 = y_test_output1.astype(np.float64)
y_pred_output1_test = y_pred_output1_test.astype(np.float64)

# Stack the original test values and predicted values horizontally
comparison_output1 = np.column_stack((y_test_output1, y_pred_output1_test))

# Print the original test values and predicted values side by side
print("Original Test Values (Output 1) vs. Predicted Values (Output 1):")
print(comparison_output1)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Original Test Values (Output 1) vs. Predicted Values (Output 1):
# [[ 0.7  0.4]
#  [ 0.3  0.1]
#  [ 1.   0.9]
#  [ 0.6  0.6]
#  [ 0.7  0.2]
#  [ 0.3  0.2]
#  [ 0.7  0.4]
#  [ 0.5  0.5]
#  [ 0.9  0.2]
#  [ 0.1  0.3]
#  [ 0.4  0.4]
#  [ 0.5  0.4]
#  [ 1.   0.6]
#  [ 0.1  0.3]
#  [ 0.2  0.6]
#  [ 0.1  0.4]
#  [ 0.7  0.8]
#  [ 0.2  0.8]
#  [ 0.9  0.8]
#  [ 0.1  0.7]
#  [ 0.6  0.3]
#  [ 0.1  0.5]
#  [ 0.3  0.3]
#  [ 0.8  0.4]
#  [ 0.7  0.3]
#  [ 0.4  0. ]
#  [ 0.7  0.4]
#  [ 0.2  0.7]
#  [ 1.   0.8]
#  [ 0.9  0.5]
#  [ 0.9  0.9]
#  [ 0.3  0.3]
#  [ 0.7  0.9]
#  [ 0.7  0.5]
#  [ 0.4  0.5]
#  [ 0.2  0.1]
#  [ 1.   0.4]
#  [ 0.9  0.8]
#  [ 0.3  0.5]
#  [ 0.1  0.5]
#  [ 1.   0.8]
#  [ 0.8  0.7]
#  [ 0.3  0.1]
#  [ 0.9  0.8]
#  [ 0.8  0.5]
#  [ 0.4  0.3]
#  [ 0.5  0.3]
#  [ 0.9  0.4]
#  [ 0.5  0.4]
#  [ 0.8  0.1]
#  [ 0.7  0.4]
#  [ 0.3  0.5]
#  [ 0.8  0.8]
#  [ 0.1  0.6]
#  [ 0.7  0.1]
#  [ 0.5  0.4]
#  [ 0.9  0.7]
#  [ 0.4  0.5]
#  [ 0.1  0.2]
#  [ 1.   1. ]
#  [ 0.6  0.6]
#  [ 0.9  0.4]
#  [ 0.9  0.5]
#  [ 1.   1. ]
#  [ 0.6  0.3]
#  [ 0.1  0.5]
#  [ 1.   0.8]
#  [ 0.5  0.2]
#  [ 1.   0.8]
#  [ 0.4  0.2]
#  [ 0.5  0.5]
#  [ 0.2  0.6]
#  [ 0.1  0.3]
#  [ 0.8  0.4]
#  [ 0.1  0.4]
#  [ 0.5  0.5]
#  [ 0.9  0.6]
#  [ 0.2  0.5]
#  [ 0.5  0.7]
#  [ 0.1  0.6]
#  [ 0.8  0.5]
#  [ 0.8  0.3]
#  [ 0.6  0.6]
#  [ 0.7  0.6]
#  [ 0.3  0.5]
#  [ 0.8  0.4]
#  [ 0.2  0.3]
#  [ 0.4  0.4]
#  [ 0.5  0.3]
#  [ 0.1  0.4]
#  [ 0.8  0.4]
#  [ 0.8  0.4]
#  [ 0.8  0.5]
#  [ 0.4  0.6]
#  [ 1.   0.6]
#  [ 0.8  0.5]
#  [ 0.9  0.9]
#  [ 0.2  0.6]
#  [ 0.6  0.5]
#  [ 0.3  0.5]
#  [ 1.   0.9]
#  [ 1.   0.6]
#  [ 0.2  0.7]
#  [ 0.5  0.4]
#  [ 0.7  0.7]
#  [ 0.9  0.9]
#  [ 0.1  0.4]
#  [ 1.   1. ]
#  [ 0.2  0.5]
#  [ 0.4  0.5]
#  [ 0.3  0.6]
#  [ 1.   0.4]
#  [ 0.4  0.4]
#  [ 0.8  0.4]
#  [ 0.4  0.3]
#  [ 0.5  0.5]
#  [ 0.3  0.3]
#  [ 0.8  0.7]
#  [ 0.2  0.2]
#  [ 0.8  0.8]
#  [ 0.9  0.6]
#  [ 0.9  0.9]
#  [ 0.5  0.4]
#  [ 0.2  0.4]
#  [ 0.1 -0.1]
#  [ 0.4  0.5]
#  [ 0.4  0.5]
#  [ 0.6  0.6]
#  [ 0.6  0.4]
#  [ 0.4  0.6]
#  [ 0.2  0.5]
#  [ 0.3  0.5]
#  [ 0.3  0.4]
#  [ 0.8  0.3]
#  [ 0.4  0.6]
#  [ 0.8  0.6]
#  [ 0.6  0.7]
#  [ 0.5  0.5]
#  [ 0.9  0.7]
#  [ 0.8  0.4]
#  [ 0.9  0.7]
#  [ 0.6  0.4]
#  [ 0.4  0.6]
#  [ 0.8  0.3]
#  [ 0.2  0.3]
#  [ 1.   0.9]
#  [ 0.7  0.8]
#  [ 0.6  0.5]
#  [ 0.3  0.6]
#  [ 0.7  0.8]
#  [ 0.2  0.2]
#  [ 0.2  0.6]
#  [ 1.   0.8]
#  [ 0.4  0.6]
#  [ 0.7  0.6]
#  [ 0.9  1. ]
#  [ 0.1  0.3]
#  [ 0.5  0.5]
#  [ 0.5  0.4]
#  [ 0.9  0.8]
#  [ 1.   0.9]
#  [ 0.6  0.5]
#  [ 0.1  0.5]
#  [ 0.2  0.4]
#  [ 0.5  0.1]
#  [ 0.4  0.4]
#  [ 0.2  0.7]
#  [ 0.9  0.6]
#  [ 0.7  0.5]
#  [ 1.   1. ]
#  [ 1.   0.7]
#  [ 0.3  0.4]
#  [ 0.7  0.7]
#  [ 0.1  0.5]
#  [ 0.8  0.3]
#  [ 0.3  0.5]
#  [ 0.8  0.6]
#  [ 0.2  0.4]
#  [ 0.7  0.3]
#  [ 1.   0.5]
#  [ 0.7  0.4]
#  [ 0.9  0.9]
#  [ 0.8  0.6]
#  [ 0.8  0.5]
#  [ 0.1  0.6]
#  [ 0.2  0.4]
#  [ 0.9  1. ]
#  [ 0.5  0.5]
#  [ 0.2  0.5]
#  [ 0.5  0.4]
#  [ 0.5  0.2]
#  [ 0.2  0.4]
#  [ 0.9  0.9]
#  [ 0.4  0.6]
#  [ 0.7  0.5]
#  [ 0.2  0.7]
#  [ 0.4  0.5]
#  [ 0.5  0.6]
#  [ 0.3  0.6]
#  [ 0.2  0.5]
#  [ 0.2  0.5]
#  [ 0.1  0.4]
#  [ 0.6  0.6]
#  [ 1.   1. ]
#  [ 0.3  0.3]
#  [ 0.3  0.6]
#  [ 1.   0.6]
#  [ 0.1  0.5]
#  [ 0.9  0.8]
#  [ 0.8  0.6]
#  [ 0.4  0.3]
#  [ 1.   0.9]
#  [ 0.5  0.5]
#  [ 0.3  0.4]
#  [ 0.1  0.5]
#  [ 0.3  0.5]
#  [ 0.1  0.4]
#  [ 0.8  0.4]
#  [ 0.4  0.2]
#  [ 0.5  0.6]
#  [ 0.6  1. ]
#  [ 0.2  0.7]
#  [ 0.1  0.2]
#  [ 1.   0.6]
#  [ 0.7  0.6]
#  [ 0.5  0.2]
#  [ 0.2  0.5]
#  [ 0.8  0.7]
#  [ 0.6  0.4]
#  [ 0.6  0.5]
#  [ 0.4  0.4]
#  [ 0.1  0.4]
#  [ 0.7  0.6]
#  [ 0.3  0.6]
#  [ 0.7  0.1]
#  [ 0.7  0.7]
#  [ 0.9  1. ]
#  [ 0.6  0.2]
#  [ 1.   0.2]
#  [ 1.   0.4]
#  [ 0.8  0.4]
#  [ 0.3  0.6]
#  [ 0.5  0.3]
#  [ 0.8  0.6]
#  [ 0.7  0.4]
#  [ 0.2  0.3]
#  [ 0.9  0.8]
#  [ 0.5  0.5]
#  [ 0.6  0.6]
#  [ 1.   0.9]
#  [ 1.   0.9]
#  [ 0.7  0.6]
#  [ 0.5  0.5]
#  [ 1.   0.9]
#  [ 0.7  0.6]
#  [ 0.4  0.2]
#  [ 0.1  0.2]
#  [ 0.2  0.4]
#  [ 0.7  0.5]
#  [ 0.7  0.7]
#  [ 0.3  0.4]
#  [ 0.5  0.2]
#  [ 0.6  0.5]
#  [ 0.1  0.1]
#  [ 0.4  0.5]
#  [ 0.5  0.5]
#  [ 0.7  0.4]
#  [ 0.2  0.2]
#  [ 0.2  0.6]
#  [ 0.5  0.5]
#  [ 0.5  0.5]
#  [ 0.8  0.6]
#  [ 1.   0.8]
#  [ 0.1  0.5]
#  [ 0.9  0.4]
#  [ 0.1  0.2]
#  [ 1.   0.9]
#  [ 0.4  0.7]
#  [ 0.4  0.7]
#  [ 0.8  0.7]
#  [ 1.   0.8]
#  [ 0.4  0.5]
#  [ 0.3  0.3]
#  [ 0.9  0.6]
#  [ 0.1  0.5]
#  [ 0.8  0.3]
#  [ 0.5  0.6]
#  [ 0.6  0.5]
#  [ 1.   0.9]
#  [ 0.8  0.5]
#  [ 0.7  0.2]
#  [ 0.8  0.7]
#  [ 0.8  0.5]
#  [ 0.4  0.8]
#  [ 0.8  0.5]
#  [ 0.2  0.2]
#  [ 0.1  0.4]
#  [ 0.5  0.4]
#  [ 0.2  0.7]
#  [ 0.5  0.4]
#  [ 0.2  1. ]
#  [ 0.4  0.6]
#  [ 0.3  0.4]
#  [ 0.8  0.5]
#  [ 0.5  0.6]
#  [ 0.9  0.8]
#  [ 0.5  0.5]
#  [ 0.7  0.7]
#  [ 0.1  0.2]
#  [ 0.2  1. ]
#  [ 0.1  0.5]
#  [ 0.9  0.9]
#  [ 0.6  0.3]
#  [ 0.8  0.4]
#  [ 0.9  0.5]
#  [ 0.4  0.7]
#  [ 0.1  0.2]
#  [ 1.   0.9]
#  [ 0.4  0.4]
#  [ 0.9  0.9]]

# %%
# 2. Generate Confusion Matrix for Classification

# Predict using the trained model on the test data for the classification output (output_2)
y_pred_output2_test = model.predict(X_test_normalized)[1]

# Convert the probability predictions to binary class labels (0 or 1)
y_pred_output2_test_binary = np.round(y_pred_output2_test).astype(int).flatten()

# Import the confusion_matrix function from sklearn.metrics
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
conf_matrix_output2 = confusion_matrix(y_test_output2, y_pred_output2_test_binary)

# Print the confusion matrix
print("Confusion Matrix (Output 2 - Classification):")
print(conf_matrix_output2)
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Confusion Matrix (Output 2 - Classification):
# [[85 82]
#  [67 86]]

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix_output2, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
